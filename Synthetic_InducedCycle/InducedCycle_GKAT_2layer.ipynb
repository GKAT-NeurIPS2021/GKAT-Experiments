# %%
# link colab to google drive directory where this project data is placed
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
################ Need to set project path here !!  #################
projectpath = # "/content/gdrive/MyDrive/GraphAttnProject/SpanTree [with start node]_[walklen=3]_[p=1,q=1]_[num_walks=50]/NIPS_Submission/"

# %%
import os
os.chdir(projectpath)
os.getcwd()
# Out:
# '/content/gdrive/MyDrive/GraphAttnProject/SpanTree [with start node]_[walklen=3]_[p=1,q=1]_[num_walks=50]/NIPS_Submission'

# %%
! pip install dgl
import dgl
# Out:
# Requirement already satisfied: dgl in /usr/local/lib/python3.7/dist-packages (0.6.1)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from dgl) (1.4.1)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.7/dist-packages (from dgl) (2.5.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from dgl) (1.19.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from dgl) (2.23.0)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx>=2.1->dgl) (4.4.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->dgl) (3.0.4)
# Using backend: pytorch

# %% [markdown]
# # Load data

# %%
from tqdm.notebook import tqdm, trange
import networkx as nx
import pickle
import numpy as np
import tensorflow as tf
import torch
print(tf.__version__)
# Out:
# 2.4.1

# %%
# load all train and validation graphs
train_graphs = pickle.load(open(f'graph_data/train_graphs.pkl', 'rb'))
val_graphs = pickle.load(open(f'graph_data/val_graphs.pkl', 'rb'))

# load all labels
train_labels = np.load('graph_data/train_labels.npy')
val_labels = np.load('graph_data/val_labels.npy')

# %%
#################. NEED TO SPECIFY THE RANDOM WALK LENGTH WE WANT TO USE ################
walk_len = 6 # we use GKAT with random walk length of 6 in this code file 
# we could also change this parameter to load GKAT kernel generated from random walks with different lengths from 2 to 10.
#########################################################################################

# %%
# here we load the frequency matriies (we could use this as raw data to do random feature mapping )

train_freq_mat = pickle.load(open(f'graph_data/GKAT_freq_mats_train_len={walk_len}.pkl', 'rb'))
val_freq_mat = pickle.load(open(f'graph_data/GKAT_freq_mats_val_len={walk_len}.pkl', 'rb'))

# %%
# here we load the pre-calculated GKAT kernel

train_GKAT_kernel = pickle.load(open(f'graph_data/GKAT_dot_kernels_train_len={walk_len}.pkl', 'rb'))
val_GKAT_kernel = pickle.load(open(f'graph_data/GKAT_dot_kernels_val_len={walk_len}.pkl', 'rb'))

# %%
GKAT_masking = [train_GKAT_kernel, val_GKAT_kernel]

# %%
train_graphs = [ dgl.from_networkx(g) for g in train_graphs]
val_graphs = [ dgl.from_networkx(g) for g in val_graphs]
info = [train_graphs, train_labels, val_graphs, val_labels, GKAT_masking]

# %% [markdown]
# # START Training

# %%
import networkx as nx
import matplotlib.pyplot as plt 
import time
import random
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm, trange
import seaborn as sns

from random import shuffle
from multiprocessing import Pool
import multiprocessing
from functools import partial
from networkx.generators.classic import cycle_graph

import sys
import scipy
import scipy.sparse

#from CodeZip_ST import *

# %%
from prettytable import PrettyTable

# this function will count the number of parameters in GKAT (will be used later in this code file)
def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %% [markdown]
# # GKAT Testing

# %% [markdown]
# ## GKAT model

# %%
class GKATLayer(nn.Module):
    def __init__(self,
                 in_dim,
                 out_dim,
                 feat_drop=0.,
                 attn_drop=0.,
                 alpha=0.2,
                 agg_activation=F.elu):
        super(GKATLayer, self).__init__()

        self.feat_drop = nn.Dropout(feat_drop)
        self.fc = nn.Linear(in_dim, out_dim, bias=False)
        #torch.nn.init.xavier_uniform_(self.fc.weight)
        #torch.nn.init.zeros_(self.fc.bias)
        self.attn_l = nn.Parameter(torch.ones(size=(out_dim, 1)))
        self.attn_r = nn.Parameter(torch.ones(size=(out_dim, 1)))
        self.attn_drop = nn.Dropout(attn_drop)
        self.activation = nn.LeakyReLU(alpha)
        self.softmax = nn.Softmax(dim = 1)

        self.agg_activation=agg_activation

    def clean_data(self):
        ndata_names = ['ft', 'a1', 'a2']
        edata_names = ['a_drop']
        for name in ndata_names:
            self.g.ndata.pop(name)
        for name in edata_names:
            self.g.edata.pop(name)

    def forward(self, feat, bg, counting_attn):

        self.g = bg
        h = self.feat_drop(feat)
        head_ft = self.fc(h).reshape((h.shape[0], -1))
        
        a1 = torch.mm(head_ft, self.attn_l)    # V x 1
        a2 = torch.mm(head_ft, self.attn_r)     # V x 1
        a = self.attn_drop(a1 + a2.transpose(0, 1))
        a = self.activation(a)

        maxes = torch.max(a, 1, keepdim=True)[0]
        a_ = a - maxes # we could subtract max to make the attention matrix bounded. (not feasible for random feature mapping decomposition)
        a_nomi = torch.mul(torch.exp(a_), counting_attn.float())
        a_deno = torch.sum(a_nomi, 1, keepdim=True)
        a_nor = a_nomi/(a_deno+1e-9)

        ret = torch.mm(a_nor, head_ft)

        if self.agg_activation is not None:
            ret = self.agg_activation(ret)

        return ret

# %%
class GKATClassifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, num_heads, n_classes, feat_drop_=0.,
                 attn_drop_=0.,):
        super(GKATClassifier, self).__init__()

        self.num_heads = num_heads
        self.hidden_dim = hidden_dim
        self.layers = nn.ModuleList([
            nn.ModuleList([GKATLayer(in_dim, hidden_dim, feat_drop = feat_drop_, attn_drop = attn_drop_, agg_activation=F.elu) for _ in range(num_heads)]),
            nn.ModuleList([GKATLayer(hidden_dim * num_heads, hidden_dim, feat_drop = feat_drop_, attn_drop = attn_drop_, agg_activation=F.elu) for _ in range(1)])
        ])
        self.classify = nn.Linear(hidden_dim * 1, n_classes)
        self.softmax = nn.Softmax(dim = 1)

    def forward(self, bg, counting_attn, normalize = 'normal'):

        h = bg.in_degrees().view(-1, 1).float() # use degree as features 
        num_nodes = h.shape[0]
        features = h.numpy().flatten()
        
        if normalize == 'normal':
            mean_ = np.mean(features)
            std_ = np.std(features)
            h = (h - mean_)/(std_+1e-9)

        for i, gnn in enumerate(self.layers):
            all_h = []
            for j, att_head in enumerate(gnn):
                all_h.append(att_head(h, bg, counting_attn))   
            h = torch.squeeze(torch.cat(all_h, dim=1))

        bg.ndata['h'] = h
        hg = dgl.mean_nodes(bg, 'h')
        return self.classify(hg)

# %%
# the following are the parameters we used in GKAT

method = 'GKAT'

runtimes = 15 # the number of repeats 

num_classes = 2 
num_features = 4 # use hidden dimension of 4 in each attention head
num_heads = 8 # use 8 heads
num_layers = 2 # use a two layer GKAT model

feature_drop = 0
atten_drop = 0

epsilon = 1e-4

start_tol = 499
tolerance = 80
max_epoch = 500
batch_size = 128
learning_rate = 0.005

# %%
all_GKAT_train_losses = []
all_GKAT_train_acc = []
all_GKAT_val_losses = []
all_GKAT_val_acc = []

ckpt_file = f'results_{num_layers}layers/{method}/{method}_ckpt.pt'

for runtime in trange(runtimes):
    

    train_graphs, train_labels, val_graphs, val_labels, GKAT_masking = info
    train_GKAT_masking, val_GKAT_masking = GKAT_masking
                                                 
    # Create model
    model = GKATClassifier(1, num_features, num_heads, num_classes, feat_drop_ = feature_drop, attn_drop_ = atten_drop)

    for p in model.parameters():
      if p.dim() > 1:
          nn.init.xavier_uniform(p)

    count_parameters(model)


    #model.apply(init_weights)
    loss_func = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)
    model.train()

    epoch_train_losses_GKAT = []
    epoch_train_acc_GKAT = []
    epoch_val_losses_GKAT = []
    epoch_val_acc_GKAT = []

    num_batches = int(len(train_graphs)/batch_size)

    epoch = 0
    nan_found = 0
    tol = 0 

    while True:
        if nan_found:
          break
        
        epoch_loss = 0
        epoch_acc = 0

        ''' Training '''
        for iter in range(num_batches):
        #for iter in range(2): 
            predictions = []
            labels = torch.empty(batch_size)
            rand_indices = np.random.choice(len(train_graphs), batch_size, replace=False)

            for b in range(batch_size): 
                predictions.append(model(train_graphs[rand_indices[b]], torch.Tensor(train_GKAT_masking[rand_indices[b]])))
                
                if torch.isnan(predictions[b][0])[0]:
                  print('NaN found.')
                  break
                #print(predictions[b].detach().numpy())
                
                labels[b] = train_labels[rand_indices[b]]
            
            acc = 0
            for k in range(len(predictions)):
              if predictions[k][0][0]>predictions[k][0][1] and labels[k]==0:
                acc += 1
              elif predictions[k][0][0]<=predictions[k][0][1] and labels[k]==1:
                acc += 1
            acc /= len(predictions)  
            epoch_acc += acc  
            
            predictions = torch.squeeze(torch.stack(predictions))
            if torch.any(torch.isnan(predictions)):
                  print('NaN found.')
                  nan_found = 1
                  break
            
            loss = loss_func(predictions, labels.long())
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            epoch_loss += loss.detach().item()

        epoch_acc /= (iter + 1)
        epoch_loss /= (iter + 1)

        val_acc = 0
        val_loss = 0
        predictions_val = []

        for b in range(len(val_graphs)): 

            predictions_val.append(model(val_graphs[b], torch.Tensor(val_GKAT_masking[b])))
        
        for k in range(len(predictions_val)):
          if predictions_val[k][0][0]>predictions_val[k][0][1] and val_labels[k]==0:
            val_acc += 1
          elif predictions_val[k][0][0]<=predictions_val[k][0][1] and val_labels[k]==1:
            val_acc += 1
              
        val_acc /= len(val_graphs)

        predictions_val = torch.squeeze(torch.stack(predictions_val))    
        loss = loss_func(predictions_val, torch.tensor(val_labels).long())
        val_loss += loss.detach().item()


        if len(epoch_val_losses_GKAT) ==0:
          try:
            os.remove(f'{projectpath}{ckpt_file}')
          except:
            pass
          torch.save(model, f'{projectpath}{ckpt_file}')
          print('Epoch {}, acc{:.2f}, loss {:.4f}, tol {}, val_acc{:.2f}, val_loss{:.4f} -- checkpoint saved'.format(epoch, epoch_acc, epoch_loss, tol, val_acc, val_loss))
        elif (np.min(epoch_val_losses_GKAT) >= val_loss) and (np.max(epoch_val_acc_GKAT) <= val_acc): 
          torch.save(model, f'{projectpath}{ckpt_file}')
          print('Epoch {}, acc{:.2f}, loss {:.4f}, tol {}, val_acc{:.2f}, val_loss{:.4f} -- checkpoint saved'.format(epoch, epoch_acc, epoch_loss, tol, val_acc, val_loss))
        else:
          print('Epoch {}, acc{:.2f}, loss {:.4f}, tol {}, val_acc{:.2f}, val_loss{:.4f}'.format(epoch, epoch_acc, epoch_loss, tol, val_acc, val_loss))


        if epoch > start_tol:
          if np.min(epoch_val_losses_GKAT) <= val_loss: 
            tol += 1
            if tol == tolerance: 
                print('Loss do not decrease')
                break
          else:
            if np.abs(epoch_val_losses_GKAT[-1] - val_loss)<epsilon:
                print('Converge steadily')
                break
            tol = 0

                    
        if epoch > max_epoch:
            print("Reach Max Epoch Number")
            break

        epoch += 1
        epoch_train_acc_GKAT.append(epoch_acc)
        epoch_train_losses_GKAT.append(epoch_loss)
        epoch_val_acc_GKAT.append(val_acc)
        epoch_val_losses_GKAT.append(val_loss)

    all_GKAT_train_acc.append(epoch_train_acc_GKAT)
    all_GKAT_train_losses.append(epoch_train_losses_GKAT)
    all_GKAT_val_acc.append(epoch_val_acc_GKAT)
    all_GKAT_val_losses.append(epoch_val_losses_GKAT)

    # save results from current repeat to the following file
    np.save(f'{projectpath}results_{num_layers}layers/epoch_train_acc_{method}_walklen{walk_len}_run{runtime}.npy', epoch_train_acc_GKAT)
    np.save(f'{projectpath}results_{num_layers}layers/epoch_val_acc_{method}_walklen{walk_len}_run{runtime}.npy', epoch_val_acc_GKAT)
    np.save(f'{projectpath}results_{num_layers}layers/epoch_train_losses_{method}_walklen{walk_len}_run{runtime}.npy', epoch_train_losses_GKAT)
    np.save(f'{projectpath}results_{num_layers}layers/epoch_val_losses_{method}_walklen{walk_len}_run{runtime}.npy', epoch_val_losses_GKAT)

# all all results to the following file
np.save(f'{projectpath}results_{num_layers}layers/all_{method}_walklen{walk_len}_train_losses.npy', all_GKAT_train_losses)
np.save(f'{projectpath}results_{num_layers}layers/all_{method}_walklen{walk_len}_train_acc.npy', all_GKAT_train_acc)
np.save(f'{projectpath}results_{num_layers}layers/all_{method}_walklen{walk_len}_val_losses.npy', all_GKAT_val_losses)
np.save(f'{projectpath}results_{num_layers}layers/all_{method}_walklen{walk_len}_val_acc.npy', all_GKAT_val_acc)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=15.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
# +----------------------+------------+
# |       Modules        | Parameters |
# +----------------------+------------+
# |  layers.0.0.attn_l   |     4      |
# |  layers.0.0.attn_r   |     4      |
# | layers.0.0.fc.weight |     4      |
# |  layers.0.1.attn_l   |     4      |
# |  layers.0.1.attn_r   |     4      |
# | layers.0.1.fc.weight |     4      |
# |  layers.0.2.attn_l   |     4      |
# |  layers.0.2.attn_r   |     4      |
# | layers.0.2.fc.weight |     4      |
# |  layers.0.3.attn_l   |     4      |
# |  layers.0.3.attn_r   |     4      |
# | layers.0.3.fc.weight |     4      |
# |  layers.0.4.attn_l   |     4      |
# |  layers.0.4.attn_r   |     4      |
# | layers.0.4.fc.weight |     4      |
# |  layers.0.5.attn_l   |     4      |
# |  layers.0.5.attn_r   |     4      |
# | layers.0.5.fc.weight |     4      |
# |  layers.0.6.attn_l   |     4      |
# |  layers.0.6.attn_r   |     4      |
# | layers.0.6.fc.weight |     4      |
# |  layers.0.7.attn_l   |     4      |
# |  layers.0.7.attn_r   |     4      |
# | layers.0.7.fc.weight |     4      |
# |  layers.1.0.attn_l   |     4      |
# |  layers.1.0.attn_r   |     4      |
# | layers.1.0.fc.weight |    128     |
# |   classify.weight    |     8      |
# |    classify.bias     |     2      |
# +----------------------+------------+
# Total Trainable Params: 242
# Epoch 0, acc0.52, loss 0.6935, tol 0, val_acc0.50, val_loss0.6946 -- checkpoint saved
# Epoch 1, acc0.52, loss 0.6946, tol 0, val_acc0.50, val_loss0.6944 -- checkpoint saved
# Epoch 2, acc0.51, loss 0.6937, tol 0, val_acc0.50, val_loss0.6999
# Epoch 3, acc0.50, loss 0.6954, tol 0, val_acc0.50, val_loss0.6949
# Epoch 4, acc0.52, loss 0.6924, tol 0, val_acc0.50, val_loss0.6941 -- checkpoint saved
# Epoch 5, acc0.52, loss 0.6926, tol 0, val_acc0.50, val_loss0.6930 -- checkpoint saved
# Epoch 6, acc0.50, loss 0.6928, tol 0, val_acc0.53, val_loss0.6913 -- checkpoint saved
# Epoch 7, acc0.54, loss 0.6907, tol 0, val_acc0.53, val_loss0.6906 -- checkpoint saved
# Epoch 8, acc0.50, loss 0.6922, tol 0, val_acc0.58, val_loss0.6883 -- checkpoint saved
# Epoch 9, acc0.53, loss 0.6913, tol 0, val_acc0.51, val_loss0.6869
# Epoch 10, acc0.61, loss 0.6844, tol 0, val_acc0.62, val_loss0.6802 -- checkpoint saved
# Epoch 11, acc0.65, loss 0.6738, tol 0, val_acc0.64, val_loss0.6674 -- checkpoint saved
# Epoch 12, acc0.63, loss 0.6591, tol 0, val_acc0.65, val_loss0.6411 -- checkpoint saved
# Epoch 13, acc0.66, loss 0.6311, tol 0, val_acc0.64, val_loss0.6207
# Epoch 14, acc0.70, loss 0.5864, tol 0, val_acc0.67, val_loss0.6093 -- checkpoint saved
# Epoch 15, acc0.68, loss 0.6144, tol 0, val_acc0.67, val_loss0.6086 -- checkpoint saved
# Epoch 16, acc0.68, loss 0.5926, tol 0, val_acc0.66, val_loss0.6014
# Epoch 17, acc0.67, loss 0.6014, tol 0, val_acc0.66, val_loss0.6029
# Epoch 18, acc0.67, loss 0.5958, tol 0, val_acc0.68, val_loss0.6024
# Epoch 19, acc0.69, loss 0.5926, tol 0, val_acc0.67, val_loss0.5968
# Epoch 20, acc0.70, loss 0.5769, tol 0, val_acc0.68, val_loss0.5937 -- checkpoint saved
# Epoch 21, acc0.69, loss 0.6015, tol 0, val_acc0.68, val_loss0.5909 -- checkpoint saved
# Epoch 22, acc0.69, loss 0.5878, tol 0, val_acc0.68, val_loss0.5883 -- checkpoint saved
# Epoch 23, acc0.72, loss 0.5663, tol 0, val_acc0.68, val_loss0.5877
# Epoch 24, acc0.71, loss 0.5740, tol 0, val_acc0.70, val_loss0.5855 -- checkpoint saved
# Epoch 25, acc0.71, loss 0.5585, tol 0, val_acc0.71, val_loss0.5769 -- checkpoint saved
# Epoch 26, acc0.69, loss 0.5806, tol 0, val_acc0.71, val_loss0.5744 -- checkpoint saved
# Epoch 27, acc0.71, loss 0.5557, tol 0, val_acc0.70, val_loss0.5656
# Epoch 28, acc0.71, loss 0.5524, tol 0, val_acc0.72, val_loss0.5614 -- checkpoint saved
# Epoch 29, acc0.73, loss 0.5459, tol 0, val_acc0.72, val_loss0.5532 -- checkpoint saved
# Epoch 30, acc0.74, loss 0.5398, tol 0, val_acc0.73, val_loss0.5509 -- checkpoint saved
# Epoch 31, acc0.73, loss 0.5244, tol 0, val_acc0.73, val_loss0.5379 -- checkpoint saved
# Epoch 32, acc0.74, loss 0.5302, tol 0, val_acc0.75, val_loss0.5236 -- checkpoint saved
# Epoch 33, acc0.77, loss 0.5181, tol 0, val_acc0.76, val_loss0.5105 -- checkpoint saved
# Epoch 34, acc0.78, loss 0.4952, tol 0, val_acc0.78, val_loss0.4893 -- checkpoint saved
# Epoch 35, acc0.80, loss 0.4722, tol 0, val_acc0.80, val_loss0.4690 -- checkpoint saved
# Epoch 36, acc0.79, loss 0.4611, tol 0, val_acc0.81, val_loss0.4468 -- checkpoint saved
# Epoch 37, acc0.82, loss 0.4180, tol 0, val_acc0.82, val_loss0.4370 -- checkpoint saved
# Epoch 38, acc0.81, loss 0.4324, tol 0, val_acc0.81, val_loss0.4333
# Epoch 39, acc0.84, loss 0.4045, tol 0, val_acc0.83, val_loss0.4060 -- checkpoint saved
# Epoch 40, acc0.83, loss 0.4165, tol 0, val_acc0.84, val_loss0.4063
# Epoch 41, acc0.83, loss 0.3926, tol 0, val_acc0.85, val_loss0.3983 -- checkpoint saved
# Epoch 42, acc0.84, loss 0.3792, tol 0, val_acc0.85, val_loss0.3660 -- checkpoint saved
# Epoch 43, acc0.83, loss 0.3909, tol 0, val_acc0.85, val_loss0.3586
# Epoch 44, acc0.82, loss 0.4082, tol 0, val_acc0.84, val_loss0.3556
# Epoch 45, acc0.85, loss 0.3654, tol 0, val_acc0.86, val_loss0.3441 -- checkpoint saved
# Epoch 46, acc0.85, loss 0.3617, tol 0, val_acc0.87, val_loss0.3414 -- checkpoint saved
# Epoch 47, acc0.85, loss 0.3545, tol 0, val_acc0.87, val_loss0.3573
# Epoch 48, acc0.84, loss 0.3701, tol 0, val_acc0.87, val_loss0.3364
# Epoch 49, acc0.85, loss 0.3630, tol 0, val_acc0.86, val_loss0.3998
# Epoch 50, acc0.85, loss 0.3429, tol 0, val_acc0.88, val_loss0.3425
# Epoch 51, acc0.86, loss 0.3423, tol 0, val_acc0.86, val_loss0.3334
# Epoch 52, acc0.86, loss 0.3411, tol 0, val_acc0.87, val_loss0.3336
# Epoch 53, acc0.86, loss 0.3567, tol 0, val_acc0.86, val_loss0.3305
# Epoch 54, acc0.86, loss 0.3205, tol 0, val_acc0.88, val_loss0.3534
# Epoch 55, acc0.86, loss 0.3310, tol 0, val_acc0.86, val_loss0.3289
# Epoch 56, acc0.87, loss 0.3152, tol 0, val_acc0.88, val_loss0.3280
# Epoch 57, acc0.86, loss 0.3432, tol 0, val_acc0.88, val_loss0.3326
# Epoch 58, acc0.86, loss 0.3072, tol 0, val_acc0.88, val_loss0.3206
# Epoch 59, acc0.88, loss 0.3126, tol 0, val_acc0.88, val_loss0.3238
# Epoch 60, acc0.88, loss 0.3185, tol 0, val_acc0.86, val_loss0.3180
# Epoch 61, acc0.85, loss 0.3518, tol 0, val_acc0.87, val_loss0.3141
# Epoch 62, acc0.88, loss 0.3106, tol 0, val_acc0.88, val_loss0.3157
# Epoch 63, acc0.87, loss 0.3141, tol 0, val_acc0.88, val_loss0.3214
# Epoch 64, acc0.84, loss 0.3588, tol 0, val_acc0.86, val_loss0.3360
# Epoch 65, acc0.86, loss 0.3480, tol 0, val_acc0.86, val_loss0.3267
# Epoch 66, acc0.87, loss 0.3425, tol 0, val_acc0.87, val_loss0.3261
# Epoch 67, acc0.86, loss 0.3342, tol 0, val_acc0.86, val_loss0.3231
# Epoch 68, acc0.86, loss 0.3380, tol 0, val_acc0.86, val_loss0.3290
# Epoch 69, acc0.86, loss 0.3407, tol 0, val_acc0.86, val_loss0.3242
# Epoch 70, acc0.88, loss 0.3402, tol 0, val_acc0.88, val_loss0.3171
# Epoch 71, acc0.89, loss 0.3126, tol 0, val_acc0.88, val_loss0.3143
# Epoch 72, acc0.86, loss 0.3262, tol 0, val_acc0.89, val_loss0.3116 -- checkpoint saved
# Epoch 73, acc0.86, loss 0.3294, tol 0, val_acc0.88, val_loss0.3105
# Epoch 74, acc0.86, loss 0.3470, tol 0, val_acc0.89, val_loss0.3096 -- checkpoint saved
# Epoch 75, acc0.87, loss 0.3240, tol 0, val_acc0.87, val_loss0.3099
# Epoch 76, acc0.88, loss 0.3045, tol 0, val_acc0.86, val_loss0.3155
# Epoch 77, acc0.86, loss 0.3376, tol 0, val_acc0.86, val_loss0.3229
# Epoch 78, acc0.87, loss 0.3143, tol 0, val_acc0.89, val_loss0.3144
# Epoch 79, acc0.87, loss 0.3392, tol 0, val_acc0.87, val_loss0.3136
# Epoch 80, acc0.88, loss 0.3178, tol 0, val_acc0.88, val_loss0.3096
# Epoch 81, acc0.87, loss 0.3290, tol 0, val_acc0.89, val_loss0.3123
# Epoch 82, acc0.87, loss 0.3251, tol 0, val_acc0.89, val_loss0.3068 -- checkpoint saved
# Epoch 83, acc0.87, loss 0.3297, tol 0, val_acc0.89, val_loss0.3052
# Epoch 84, acc0.87, loss 0.3209, tol 0, val_acc0.88, val_loss0.3046
# Epoch 85, acc0.86, loss 0.3448, tol 0, val_acc0.87, val_loss0.3070
# Epoch 86, acc0.86, loss 0.3212, tol 0, val_acc0.87, val_loss0.3079
# Epoch 87, acc0.86, loss 0.3336, tol 0, val_acc0.89, val_loss0.3050
# Epoch 88, acc0.85, loss 0.3501, tol 0, val_acc0.89, val_loss0.3210
# Epoch 89, acc0.88, loss 0.3066, tol 0, val_acc0.89, val_loss0.3125
# Epoch 90, acc0.87, loss 0.3233, tol 0, val_acc0.89, val_loss0.3043
# Epoch 91, acc0.87, loss 0.3220, tol 0, val_acc0.87, val_loss0.3065
# Epoch 92, acc0.87, loss 0.3341, tol 0, val_acc0.89, val_loss0.3074
# Epoch 93, acc0.86, loss 0.3178, tol 0, val_acc0.89, val_loss0.3325
# Epoch 94, acc0.86, loss 0.3693, tol 0, val_acc0.88, val_loss0.3265
# Epoch 95, acc0.87, loss 0.3283, tol 0, val_acc0.88, val_loss0.3143
# Epoch 96, acc0.88, loss 0.2953, tol 0, val_acc0.89, val_loss0.3045
# Epoch 97, acc0.86, loss 0.3409, tol 0, val_acc0.89, val_loss0.3009
# Epoch 98, acc0.87, loss 0.3245, tol 0, val_acc0.87, val_loss0.3042
# Epoch 99, acc0.88, loss 0.3127, tol 0, val_acc0.89, val_loss0.3018
# Epoch 100, acc0.87, loss 0.3310, tol 0, val_acc0.89, val_loss0.3152
# Epoch 101, acc0.87, loss 0.3320, tol 0, val_acc0.88, val_loss0.3041
# Epoch 102, acc0.87, loss 0.3295, tol 0, val_acc0.87, val_loss0.3082
# Epoch 103, acc0.87, loss 0.3530, tol 0, val_acc0.87, val_loss0.3061
# Epoch 104, acc0.88, loss 0.2924, tol 0, val_acc0.88, val_loss0.2984
# Epoch 105, acc0.86, loss 0.3036, tol 0, val_acc0.89, val_loss0.2999
# Epoch 106, acc0.88, loss 0.3160, tol 0, val_acc0.88, val_loss0.3028
# Epoch 107, acc0.87, loss 0.3188, tol 0, val_acc0.89, val_loss0.3182
# Epoch 108, acc0.87, loss 0.3391, tol 0, val_acc0.88, val_loss0.3052
# Epoch 109, acc0.87, loss 0.3282, tol 0, val_acc0.88, val_loss0.2987
# Epoch 110, acc0.87, loss 0.3167, tol 0, val_acc0.87, val_loss0.3133
# Epoch 111, acc0.86, loss 0.3619, tol 0, val_acc0.88, val_loss0.3044
# Epoch 112, acc0.88, loss 0.3147, tol 0, val_acc0.87, val_loss0.3226
# Epoch 113, acc0.87, loss 0.3357, tol 0, val_acc0.87, val_loss0.3168
# Epoch 114, acc0.87, loss 0.3329, tol 0, val_acc0.88, val_loss0.2999
# Epoch 115, acc0.88, loss 0.2962, tol 0, val_acc0.88, val_loss0.3015
# Epoch 116, acc0.88, loss 0.2893, tol 0, val_acc0.88, val_loss0.2971
# Epoch 117, acc0.88, loss 0.2922, tol 0, val_acc0.89, val_loss0.3076
# Epoch 118, acc0.86, loss 0.3357, tol 0, val_acc0.89, val_loss0.3187
# Epoch 119, acc0.87, loss 0.3352, tol 0, val_acc0.89, val_loss0.3134
# Epoch 120, acc0.87, loss 0.3125, tol 0, val_acc0.89, val_loss0.3065
# Epoch 121, acc0.88, loss 0.3145, tol 0, val_acc0.88, val_loss0.3084
# Epoch 122, acc0.86, loss 0.3337, tol 0, val_acc0.89, val_loss0.2954 -- checkpoint saved
# Epoch 123, acc0.88, loss 0.2962, tol 0, val_acc0.89, val_loss0.2954
# Epoch 124, acc0.89, loss 0.2876, tol 0, val_acc0.88, val_loss0.2943
# Epoch 125, acc0.88, loss 0.2938, tol 0, val_acc0.88, val_loss0.2963
# Epoch 126, acc0.89, loss 0.2716, tol 0, val_acc0.88, val_loss0.2901
# Epoch 127, acc0.88, loss 0.3096, tol 0, val_acc0.87, val_loss0.3076
# Epoch 128, acc0.87, loss 0.3211, tol 0, val_acc0.87, val_loss0.3066
# Epoch 129, acc0.87, loss 0.3249, tol 0, val_acc0.89, val_loss0.2889
# Epoch 130, acc0.89, loss 0.3091, tol 0, val_acc0.89, val_loss0.2883
# Epoch 131, acc0.90, loss 0.2864, tol 0, val_acc0.90, val_loss0.3067
# Epoch 132, acc0.87, loss 0.3028, tol 0, val_acc0.88, val_loss0.3004
# Epoch 133, acc0.87, loss 0.3231, tol 0, val_acc0.88, val_loss0.2903
# Epoch 134, acc0.87, loss 0.3062, tol 0, val_acc0.89, val_loss0.2857
# Epoch 135, acc0.86, loss 0.3101, tol 0, val_acc0.89, val_loss0.2838
# Epoch 136, acc0.88, loss 0.3175, tol 0, val_acc0.89, val_loss0.3183
# Epoch 137, acc0.86, loss 0.3425, tol 0, val_acc0.88, val_loss0.3540
# Epoch 138, acc0.87, loss 0.3350, tol 0, val_acc0.89, val_loss0.3184
# Epoch 139, acc0.87, loss 0.3258, tol 0, val_acc0.90, val_loss0.2940
# Epoch 140, acc0.89, loss 0.2967, tol 0, val_acc0.89, val_loss0.2859
# Epoch 141, acc0.88, loss 0.2942, tol 0, val_acc0.90, val_loss0.2847
# Epoch 142, acc0.87, loss 0.3174, tol 0, val_acc0.89, val_loss0.2823
# Epoch 143, acc0.88, loss 0.2925, tol 0, val_acc0.90, val_loss0.2911
# Epoch 144, acc0.88, loss 0.2989, tol 0, val_acc0.90, val_loss0.2849
# Epoch 145, acc0.88, loss 0.3163, tol 0, val_acc0.88, val_loss0.2884
# Epoch 146, acc0.89, loss 0.2919, tol 0, val_acc0.90, val_loss0.2802
# Epoch 147, acc0.88, loss 0.3094, tol 0, val_acc0.90, val_loss0.2816
# Epoch 148, acc0.88, loss 0.3209, tol 0, val_acc0.90, val_loss0.2899
# Epoch 149, acc0.87, loss 0.3096, tol 0, val_acc0.90, val_loss0.2863
# Epoch 150, acc0.88, loss 0.3200, tol 0, val_acc0.90, val_loss0.2806
# Epoch 151, acc0.89, loss 0.2970, tol 0, val_acc0.89, val_loss0.2862
# Epoch 152, acc0.88, loss 0.2895, tol 0, val_acc0.89, val_loss0.2821
# Epoch 153, acc0.89, loss 0.2887, tol 0, val_acc0.89, val_loss0.2810
# Epoch 154, acc0.88, loss 0.3026, tol 0, val_acc0.88, val_loss0.2991
# Epoch 155, acc0.87, loss 0.3115, tol 0, val_acc0.89, val_loss0.2811
# Epoch 156, acc0.88, loss 0.3142, tol 0, val_acc0.91, val_loss0.2984
# Epoch 157, acc0.88, loss 0.3157, tol 0, val_acc0.90, val_loss0.2819
# Epoch 158, acc0.87, loss 0.3061, tol 0, val_acc0.89, val_loss0.2799
# Epoch 159, acc0.88, loss 0.3018, tol 0, val_acc0.89, val_loss0.2816
# Epoch 160, acc0.88, loss 0.2907, tol 0, val_acc0.90, val_loss0.2781
# Epoch 161, acc0.89, loss 0.2810, tol 0, val_acc0.90, val_loss0.2764
# Epoch 162, acc0.89, loss 0.2932, tol 0, val_acc0.90, val_loss0.2775
# Epoch 163, acc0.90, loss 0.2695, tol 0, val_acc0.89, val_loss0.2820
# Epoch 164, acc0.88, loss 0.3065, tol 0, val_acc0.89, val_loss0.2842
# Epoch 165, acc0.87, loss 0.2949, tol 0, val_acc0.89, val_loss0.2769
# Epoch 166, acc0.88, loss 0.2777, tol 0, val_acc0.89, val_loss0.2766
# Epoch 167, acc0.89, loss 0.2828, tol 0, val_acc0.89, val_loss0.2810
# Epoch 168, acc0.90, loss 0.2644, tol 0, val_acc0.88, val_loss0.2952
# Epoch 169, acc0.89, loss 0.3070, tol 0, val_acc0.90, val_loss0.2796
# Epoch 170, acc0.89, loss 0.2718, tol 0, val_acc0.90, val_loss0.2811
# Epoch 171, acc0.89, loss 0.2727, tol 0, val_acc0.89, val_loss0.2833
# Epoch 172, acc0.88, loss 0.2890, tol 0, val_acc0.89, val_loss0.2794
# Epoch 173, acc0.88, loss 0.3092, tol 0, val_acc0.89, val_loss0.2765
# Epoch 174, acc0.90, loss 0.2833, tol 0, val_acc0.90, val_loss0.2756
# Epoch 175, acc0.90, loss 0.2990, tol 0, val_acc0.89, val_loss0.2832
# Epoch 176, acc0.87, loss 0.3219, tol 0, val_acc0.90, val_loss0.2792
# Epoch 177, acc0.88, loss 0.3151, tol 0, val_acc0.90, val_loss0.2731
# Epoch 178, acc0.88, loss 0.3032, tol 0, val_acc0.89, val_loss0.2706
# Epoch 179, acc0.88, loss 0.2910, tol 0, val_acc0.90, val_loss0.2709
# Epoch 180, acc0.90, loss 0.2728, tol 0, val_acc0.90, val_loss0.2737
# Epoch 181, acc0.89, loss 0.2797, tol 0, val_acc0.90, val_loss0.2746
# Epoch 182, acc0.88, loss 0.2864, tol 0, val_acc0.89, val_loss0.2731
# Epoch 183, acc0.89, loss 0.3005, tol 0, val_acc0.88, val_loss0.2979
# Epoch 184, acc0.88, loss 0.2892, tol 0, val_acc0.90, val_loss0.2792
# Epoch 185, acc0.91, loss 0.2422, tol 0, val_acc0.90, val_loss0.2742
# Epoch 186, acc0.90, loss 0.2626, tol 0, val_acc0.90, val_loss0.2778
# Epoch 187, acc0.89, loss 0.2805, tol 0, val_acc0.91, val_loss0.2704 -- checkpoint saved
# Epoch 188, acc0.89, loss 0.2715, tol 0, val_acc0.89, val_loss0.2718
# Epoch 189, acc0.90, loss 0.2822, tol 0, val_acc0.89, val_loss0.2709
# Epoch 190, acc0.90, loss 0.2607, tol 0, val_acc0.89, val_loss0.2712
# Epoch 191, acc0.89, loss 0.2781, tol 0, val_acc0.90, val_loss0.2699
# Epoch 192, acc0.89, loss 0.2835, tol 0, val_acc0.90, val_loss0.2738
# Epoch 193, acc0.89, loss 0.2705, tol 0, val_acc0.90, val_loss0.2698
# Epoch 194, acc0.87, loss 0.3106, tol 0, val_acc0.90, val_loss0.2770
# Epoch 195, acc0.89, loss 0.2760, tol 0, val_acc0.90, val_loss0.2736
# Epoch 196, acc0.89, loss 0.2801, tol 0, val_acc0.90, val_loss0.2723
# Epoch 197, acc0.88, loss 0.2978, tol 0, val_acc0.89, val_loss0.2742
# Epoch 198, acc0.89, loss 0.2744, tol 0, val_acc0.90, val_loss0.2715
# Epoch 199, acc0.90, loss 0.2766, tol 0, val_acc0.89, val_loss0.2761
# Epoch 200, acc0.89, loss 0.3025, tol 0, val_acc0.89, val_loss0.2812
# Epoch 201, acc0.86, loss 0.3234, tol 0, val_acc0.90, val_loss0.2731
# Epoch 202, acc0.88, loss 0.3193, tol 0, val_acc0.90, val_loss0.2726
# Epoch 203, acc0.87, loss 0.3124, tol 0, val_acc0.90, val_loss0.2845
# Epoch 204, acc0.88, loss 0.3126, tol 0, val_acc0.89, val_loss0.2722
# Epoch 205, acc0.89, loss 0.2917, tol 0, val_acc0.91, val_loss0.2885
# Epoch 206, acc0.89, loss 0.2836, tol 0, val_acc0.90, val_loss0.2765
# Epoch 207, acc0.88, loss 0.2963, tol 0, val_acc0.90, val_loss0.2711
# Epoch 208, acc0.88, loss 0.2913, tol 0, val_acc0.90, val_loss0.2701
# Epoch 209, acc0.90, loss 0.2400, tol 0, val_acc0.90, val_loss0.2686
# Epoch 210, acc0.87, loss 0.2939, tol 0, val_acc0.90, val_loss0.2689
# Epoch 211, acc0.90, loss 0.2693, tol 0, val_acc0.90, val_loss0.2691
# Epoch 212, acc0.89, loss 0.2861, tol 0, val_acc0.90, val_loss0.2656
# Epoch 213, acc0.89, loss 0.2806, tol 0, val_acc0.90, val_loss0.2668
# Epoch 214, acc0.88, loss 0.3082, tol 0, val_acc0.91, val_loss0.2677
# Epoch 215, acc0.91, loss 0.2638, tol 0, val_acc0.90, val_loss0.2774
# Epoch 216, acc0.90, loss 0.2689, tol 0, val_acc0.90, val_loss0.2765
# Epoch 217, acc0.92, loss 0.2433, tol 0, val_acc0.89, val_loss0.2695
# Epoch 218, acc0.88, loss 0.2892, tol 0, val_acc0.91, val_loss0.2712
# Epoch 219, acc0.91, loss 0.2645, tol 0, val_acc0.90, val_loss0.2776
# Epoch 220, acc0.88, loss 0.2793, tol 0, val_acc0.90, val_loss0.2664
# Epoch 221, acc0.89, loss 0.2812, tol 0, val_acc0.90, val_loss0.2684
# Epoch 222, acc0.90, loss 0.2725, tol 0, val_acc0.90, val_loss0.2692
# Epoch 223, acc0.90, loss 0.2748, tol 0, val_acc0.91, val_loss0.2678
# Epoch 224, acc0.89, loss 0.2618, tol 0, val_acc0.90, val_loss0.2666
# Epoch 225, acc0.89, loss 0.2839, tol 0, val_acc0.90, val_loss0.2645
# Epoch 226, acc0.89, loss 0.2675, tol 0, val_acc0.90, val_loss0.2646
# Epoch 227, acc0.90, loss 0.2712, tol 0, val_acc0.90, val_loss0.2646
# Epoch 228, acc0.89, loss 0.2728, tol 0, val_acc0.91, val_loss0.2848
# Epoch 229, acc0.88, loss 0.3029, tol 0, val_acc0.91, val_loss0.2637
# Epoch 230, acc0.90, loss 0.2713, tol 0, val_acc0.90, val_loss0.2620
# Epoch 231, acc0.90, loss 0.2741, tol 0, val_acc0.90, val_loss0.2619
# Epoch 232, acc0.89, loss 0.2852, tol 0, val_acc0.90, val_loss0.2595
# Epoch 233, acc0.91, loss 0.2601, tol 0, val_acc0.90, val_loss0.2638
# Epoch 234, acc0.89, loss 0.2686, tol 0, val_acc0.90, val_loss0.2601
# Epoch 235, acc0.89, loss 0.2920, tol 0, val_acc0.90, val_loss0.2680
# Epoch 236, acc0.88, loss 0.2795, tol 0, val_acc0.89, val_loss0.2690
# Epoch 237, acc0.88, loss 0.2983, tol 0, val_acc0.89, val_loss0.2685
# Epoch 238, acc0.89, loss 0.2978, tol 0, val_acc0.91, val_loss0.2995
# Epoch 239, acc0.89, loss 0.2988, tol 0, val_acc0.91, val_loss0.2894
# Epoch 240, acc0.88, loss 0.3158, tol 0, val_acc0.91, val_loss0.2792
# Epoch 241, acc0.90, loss 0.2789, tol 0, val_acc0.90, val_loss0.3274
# Epoch 242, acc0.89, loss 0.3092, tol 0, val_acc0.91, val_loss0.2862
# Epoch 243, acc0.89, loss 0.3087, tol 0, val_acc0.91, val_loss0.2889
# Epoch 244, acc0.91, loss 0.2492, tol 0, val_acc0.89, val_loss0.2724
# Epoch 245, acc0.90, loss 0.2715, tol 0, val_acc0.91, val_loss0.2664
# Epoch 246, acc0.91, loss 0.2560, tol 0, val_acc0.90, val_loss0.2637
# Epoch 247, acc0.90, loss 0.2734, tol 0, val_acc0.90, val_loss0.2677
# Epoch 248, acc0.87, loss 0.3059, tol 0, val_acc0.91, val_loss0.2657
# Epoch 249, acc0.90, loss 0.2670, tol 0, val_acc0.90, val_loss0.2723
# Epoch 250, acc0.91, loss 0.2636, tol 0, val_acc0.91, val_loss0.2650
# Epoch 251, acc0.90, loss 0.2564, tol 0, val_acc0.91, val_loss0.2713
# Epoch 252, acc0.89, loss 0.2892, tol 0, val_acc0.90, val_loss0.2676
# Epoch 253, acc0.89, loss 0.2862, tol 0, val_acc0.91, val_loss0.2655
# Epoch 254, acc0.90, loss 0.2736, tol 0, val_acc0.90, val_loss0.2654
# Epoch 255, acc0.88, loss 0.2937, tol 0, val_acc0.89, val_loss0.2802
# Epoch 256, acc0.90, loss 0.2747, tol 0, val_acc0.89, val_loss0.2856
# Epoch 257, acc0.88, loss 0.2891, tol 0, val_acc0.89, val_loss0.2866
# Epoch 258, acc0.88, loss 0.2965, tol 0, val_acc0.89, val_loss0.2753
# Epoch 259, acc0.91, loss 0.2454, tol 0, val_acc0.91, val_loss0.2646
# Epoch 260, acc0.90, loss 0.2717, tol 0, val_acc0.90, val_loss0.2638
# Epoch 261, acc0.88, loss 0.2829, tol 0, val_acc0.90, val_loss0.2634
# Epoch 262, acc0.91, loss 0.2697, tol 0, val_acc0.91, val_loss0.2650
# Epoch 263, acc0.88, loss 0.3042, tol 0, val_acc0.91, val_loss0.2652
# Epoch 264, acc0.90, loss 0.2769, tol 0, val_acc0.90, val_loss0.2630
# Epoch 265, acc0.89, loss 0.3011, tol 0, val_acc0.89, val_loss0.2666
# Epoch 266, acc0.90, loss 0.2724, tol 0, val_acc0.90, val_loss0.2633
# Epoch 267, acc0.90, loss 0.2644, tol 0, val_acc0.88, val_loss0.2896
# Epoch 268, acc0.90, loss 0.2919, tol 0, val_acc0.89, val_loss0.2706
# Epoch 269, acc0.89, loss 0.3001, tol 0, val_acc0.91, val_loss0.2724
# Epoch 270, acc0.89, loss 0.2840, tol 0, val_acc0.90, val_loss0.2732
# Epoch 271, acc0.90, loss 0.2603, tol 0, val_acc0.91, val_loss0.2763
# Epoch 272, acc0.91, loss 0.2512, tol 0, val_acc0.91, val_loss0.2937
# Epoch 273, acc0.89, loss 0.2903, tol 0, val_acc0.91, val_loss0.2937
# Epoch 274, acc0.89, loss 0.2654, tol 0, val_acc0.91, val_loss0.2787
# Epoch 275, acc0.87, loss 0.3337, tol 0, val_acc0.90, val_loss0.2644
# Epoch 276, acc0.89, loss 0.2853, tol 0, val_acc0.90, val_loss0.2605
# Epoch 277, acc0.90, loss 0.2562, tol 0, val_acc0.89, val_loss0.2685
# Epoch 278, acc0.89, loss 0.2961, tol 0, val_acc0.89, val_loss0.2729
# Epoch 279, acc0.89, loss 0.2894, tol 0, val_acc0.89, val_loss0.2666
# Epoch 280, acc0.89, loss 0.2835, tol 0, val_acc0.89, val_loss0.2741
# Epoch 281, acc0.89, loss 0.2920, tol 0, val_acc0.90, val_loss0.2798
# Epoch 282, acc0.88, loss 0.2837, tol 0, val_acc0.91, val_loss0.2640
# Epoch 283, acc0.90, loss 0.2760, tol 0, val_acc0.91, val_loss0.2911
# Epoch 284, acc0.89, loss 0.2718, tol 0, val_acc0.90, val_loss0.2641
# Epoch 285, acc0.88, loss 0.2939, tol 0, val_acc0.90, val_loss0.2659
# Epoch 286, acc0.90, loss 0.2823, tol 0, val_acc0.90, val_loss0.2667
# Epoch 287, acc0.91, loss 0.2630, tol 0, val_acc0.89, val_loss0.2702
# Epoch 288, acc0.92, loss 0.2676, tol 0, val_acc0.89, val_loss0.2928
# Epoch 289, acc0.89, loss 0.2548, tol 0, val_acc0.89, val_loss0.2720
# Epoch 290, acc0.89, loss 0.2796, tol 0, val_acc0.91, val_loss0.2663
# Epoch 291, acc0.90, loss 0.2642, tol 0, val_acc0.91, val_loss0.2667
# Epoch 292, acc0.90, loss 0.2755, tol 0, val_acc0.91, val_loss0.2610
# Epoch 293, acc0.90, loss 0.2607, tol 0, val_acc0.90, val_loss0.2613
# Epoch 294, acc0.88, loss 0.3012, tol 0, val_acc0.90, val_loss0.2681
# Epoch 295, acc0.90, loss 0.2796, tol 0, val_acc0.89, val_loss0.2880
# Epoch 296, acc0.90, loss 0.2782, tol 0, val_acc0.90, val_loss0.2742
# Epoch 297, acc0.91, loss 0.2455, tol 0, val_acc0.90, val_loss0.2663
# Epoch 298, acc0.90, loss 0.2666, tol 0, val_acc0.90, val_loss0.2654
# Epoch 299, acc0.90, loss 0.2741, tol 0, val_acc0.91, val_loss0.2688
# Epoch 300, acc0.90, loss 0.2714, tol 0, val_acc0.90, val_loss0.2679
# Epoch 301, acc0.89, loss 0.2554, tol 0, val_acc0.89, val_loss0.2706
# Epoch 302, acc0.90, loss 0.2603, tol 0, val_acc0.90, val_loss0.2628
# Epoch 303, acc0.91, loss 0.2197, tol 0, val_acc0.89, val_loss0.2703
# Epoch 304, acc0.90, loss 0.2580, tol 0, val_acc0.91, val_loss0.2735
# Epoch 305, acc0.89, loss 0.2560, tol 0, val_acc0.91, val_loss0.2650
# Epoch 306, acc0.89, loss 0.2722, tol 0, val_acc0.90, val_loss0.2628
# Epoch 307, acc0.90, loss 0.2872, tol 0, val_acc0.91, val_loss0.2598
# Epoch 308, acc0.90, loss 0.2600, tol 0, val_acc0.91, val_loss0.2598
# Epoch 309, acc0.90, loss 0.2502, tol 0, val_acc0.90, val_loss0.2616
# Epoch 310, acc0.89, loss 0.2605, tol 0, val_acc0.91, val_loss0.2692
# Epoch 311, acc0.90, loss 0.2579, tol 0, val_acc0.91, val_loss0.2702
# Epoch 312, acc0.91, loss 0.2507, tol 0, val_acc0.90, val_loss0.2624
# Epoch 313, acc0.90, loss 0.2569, tol 0, val_acc0.91, val_loss0.2642
# Epoch 314, acc0.89, loss 0.3023, tol 0, val_acc0.91, val_loss0.2587
# Epoch 315, acc0.88, loss 0.3005, tol 0, val_acc0.90, val_loss0.2612
# Epoch 316, acc0.90, loss 0.2787, tol 0, val_acc0.90, val_loss0.2618
# Epoch 317, acc0.88, loss 0.3030, tol 0, val_acc0.89, val_loss0.2711
# Epoch 318, acc0.90, loss 0.2771, tol 0, val_acc0.90, val_loss0.2621
# Epoch 319, acc0.91, loss 0.2489, tol 0, val_acc0.90, val_loss0.2622
# Epoch 320, acc0.87, loss 0.3012, tol 0, val_acc0.91, val_loss0.2635
# Epoch 321, acc0.90, loss 0.2526, tol 0, val_acc0.91, val_loss0.2606
# Epoch 322, acc0.89, loss 0.2612, tol 0, val_acc0.91, val_loss0.2600
# Epoch 323, acc0.91, loss 0.2504, tol 0, val_acc0.91, val_loss0.2585
# Epoch 324, acc0.91, loss 0.2606, tol 0, val_acc0.91, val_loss0.2587
# Epoch 325, acc0.91, loss 0.2411, tol 0, val_acc0.91, val_loss0.2593
# Epoch 326, acc0.90, loss 0.2627, tol 0, val_acc0.91, val_loss0.2575
# Epoch 327, acc0.89, loss 0.2669, tol 0, val_acc0.91, val_loss0.2594
# Epoch 328, acc0.91, loss 0.2630, tol 0, val_acc0.90, val_loss0.2595
# Epoch 329, acc0.88, loss 0.2942, tol 0, val_acc0.91, val_loss0.2572
# Epoch 330, acc0.92, loss 0.2241, tol 0, val_acc0.91, val_loss0.2565
# Epoch 331, acc0.90, loss 0.2647, tol 0, val_acc0.90, val_loss0.2565
# Epoch 332, acc0.91, loss 0.2470, tol 0, val_acc0.90, val_loss0.2549
# Epoch 333, acc0.91, loss 0.2381, tol 0, val_acc0.90, val_loss0.2564
# Epoch 334, acc0.90, loss 0.2675, tol 0, val_acc0.91, val_loss0.2556
# Epoch 335, acc0.90, loss 0.2682, tol 0, val_acc0.91, val_loss0.2666
# Epoch 336, acc0.91, loss 0.2289, tol 0, val_acc0.90, val_loss0.2612
# Epoch 337, acc0.89, loss 0.2829, tol 0, val_acc0.89, val_loss0.2711
# Epoch 338, acc0.90, loss 0.2496, tol 0, val_acc0.90, val_loss0.2619
# Epoch 339, acc0.91, loss 0.2715, tol 0, val_acc0.91, val_loss0.2546
# Epoch 340, acc0.90, loss 0.2574, tol 0, val_acc0.91, val_loss0.2526 -- checkpoint saved
# Epoch 341, acc0.91, loss 0.2682, tol 0, val_acc0.91, val_loss0.2551
# Epoch 342, acc0.91, loss 0.2498, tol 0, val_acc0.91, val_loss0.2537
# Epoch 343, acc0.90, loss 0.2626, tol 0, val_acc0.91, val_loss0.2620
# Epoch 344, acc0.89, loss 0.2677, tol 0, val_acc0.91, val_loss0.2600
# Epoch 345, acc0.89, loss 0.3040, tol 0, val_acc0.92, val_loss0.2561
# Epoch 346, acc0.91, loss 0.2478, tol 0, val_acc0.92, val_loss0.2579
# Epoch 347, acc0.91, loss 0.2546, tol 0, val_acc0.89, val_loss0.2628
# Epoch 348, acc0.90, loss 0.2575, tol 0, val_acc0.91, val_loss0.2587
# Epoch 349, acc0.91, loss 0.2559, tol 0, val_acc0.91, val_loss0.2592
# Epoch 350, acc0.91, loss 0.2493, tol 0, val_acc0.92, val_loss0.2600
# Epoch 351, acc0.90, loss 0.2756, tol 0, val_acc0.91, val_loss0.2548
# Epoch 352, acc0.91, loss 0.2538, tol 0, val_acc0.91, val_loss0.2539
# Epoch 353, acc0.90, loss 0.2675, tol 0, val_acc0.91, val_loss0.2515
# Epoch 354, acc0.91, loss 0.2376, tol 0, val_acc0.92, val_loss0.2621
# Epoch 355, acc0.90, loss 0.2699, tol 0, val_acc0.91, val_loss0.2486
# Epoch 356, acc0.89, loss 0.2907, tol 0, val_acc0.91, val_loss0.2536
# Epoch 357, acc0.90, loss 0.2857, tol 0, val_acc0.91, val_loss0.2591
# Epoch 358, acc0.91, loss 0.2571, tol 0, val_acc0.91, val_loss0.2503
# Epoch 359, acc0.89, loss 0.2941, tol 0, val_acc0.91, val_loss0.2542
# Epoch 360, acc0.89, loss 0.2725, tol 0, val_acc0.91, val_loss0.2545
# Epoch 361, acc0.92, loss 0.2424, tol 0, val_acc0.91, val_loss0.2587
# Epoch 362, acc0.90, loss 0.2820, tol 0, val_acc0.91, val_loss0.2548
# Epoch 363, acc0.90, loss 0.2598, tol 0, val_acc0.90, val_loss0.2566
# Epoch 364, acc0.89, loss 0.2684, tol 0, val_acc0.92, val_loss0.2526
# Epoch 365, acc0.89, loss 0.3015, tol 0, val_acc0.92, val_loss0.2756
# Epoch 366, acc0.89, loss 0.2978, tol 0, val_acc0.91, val_loss0.2550
# Epoch 367, acc0.90, loss 0.2638, tol 0, val_acc0.90, val_loss0.2576
# Epoch 368, acc0.90, loss 0.2749, tol 0, val_acc0.89, val_loss0.2617
# Epoch 369, acc0.90, loss 0.2643, tol 0, val_acc0.91, val_loss0.2544
# Epoch 370, acc0.90, loss 0.2608, tol 0, val_acc0.91, val_loss0.2631
# Epoch 371, acc0.89, loss 0.2729, tol 0, val_acc0.91, val_loss0.2623
# Epoch 372, acc0.90, loss 0.2766, tol 0, val_acc0.92, val_loss0.2683
# Epoch 373, acc0.89, loss 0.2555, tol 0, val_acc0.92, val_loss0.2525
# Epoch 374, acc0.89, loss 0.2937, tol 0, val_acc0.91, val_loss0.2539
# Epoch 375, acc0.90, loss 0.2642, tol 0, val_acc0.89, val_loss0.2639
# Epoch 376, acc0.88, loss 0.2885, tol 0, val_acc0.89, val_loss0.2754
# Epoch 377, acc0.89, loss 0.2864, tol 0, val_acc0.91, val_loss0.2578
# Epoch 378, acc0.90, loss 0.2728, tol 0, val_acc0.91, val_loss0.2524
# Epoch 379, acc0.87, loss 0.3122, tol 0, val_acc0.92, val_loss0.2587
# Epoch 380, acc0.89, loss 0.3015, tol 0, val_acc0.91, val_loss0.2645
# Epoch 381, acc0.90, loss 0.2795, tol 0, val_acc0.89, val_loss0.2671
# Epoch 382, acc0.89, loss 0.2809, tol 0, val_acc0.89, val_loss0.2776
# Epoch 383, acc0.92, loss 0.2234, tol 0, val_acc0.91, val_loss0.2543
# Epoch 384, acc0.90, loss 0.2574, tol 0, val_acc0.92, val_loss0.2622
# Epoch 385, acc0.91, loss 0.2592, tol 0, val_acc0.92, val_loss0.2622
# Epoch 386, acc0.91, loss 0.2555, tol 0, val_acc0.92, val_loss0.2605
# Epoch 387, acc0.89, loss 0.2959, tol 0, val_acc0.92, val_loss0.2699
# Epoch 388, acc0.92, loss 0.2602, tol 0, val_acc0.92, val_loss0.2543
# Epoch 389, acc0.91, loss 0.2568, tol 0, val_acc0.92, val_loss0.2690
# Epoch 390, acc0.91, loss 0.2542, tol 0, val_acc0.91, val_loss0.2567
# Epoch 391, acc0.90, loss 0.2740, tol 0, val_acc0.92, val_loss0.2549
# Epoch 392, acc0.91, loss 0.2539, tol 0, val_acc0.90, val_loss0.2621
# Epoch 393, acc0.91, loss 0.2616, tol 0, val_acc0.91, val_loss0.2582
# Epoch 394, acc0.90, loss 0.2618, tol 0, val_acc0.91, val_loss0.2555
# Epoch 395, acc0.91, loss 0.2574, tol 0, val_acc0.91, val_loss0.2545
# Epoch 396, acc0.90, loss 0.2642, tol 0, val_acc0.92, val_loss0.2530
# Epoch 397, acc0.91, loss 0.2355, tol 0, val_acc0.92, val_loss0.2627
# Epoch 398, acc0.89, loss 0.3024, tol 0, val_acc0.92, val_loss0.2749
# Epoch 399, acc0.91, loss 0.2431, tol 0, val_acc0.91, val_loss0.2560
# Epoch 400, acc0.91, loss 0.2634, tol 0, val_acc0.91, val_loss0.2608
# Epoch 401, acc0.90, loss 0.2658, tol 0, val_acc0.92, val_loss0.2798
# Epoch 402, acc0.90, loss 0.2540, tol 0, val_acc0.92, val_loss0.2675
# Epoch 403, acc0.91, loss 0.2414, tol 0, val_acc0.92, val_loss0.2716
# Epoch 404, acc0.90, loss 0.2693, tol 0, val_acc0.92, val_loss0.2633
# Epoch 405, acc0.90, loss 0.2522, tol 0, val_acc0.92, val_loss0.2770
# Epoch 406, acc0.91, loss 0.2598, tol 0, val_acc0.91, val_loss0.2635
# Epoch 407, acc0.92, loss 0.2293, tol 0, val_acc0.92, val_loss0.2533
# Epoch 408, acc0.89, loss 0.2775, tol 0, val_acc0.92, val_loss0.2810
# Epoch 409, acc0.91, loss 0.2545, tol 0, val_acc0.92, val_loss0.2571
# Epoch 410, acc0.89, loss 0.2630, tol 0, val_acc0.91, val_loss0.2517
# Epoch 411, acc0.91, loss 0.2577, tol 0, val_acc0.89, val_loss0.2647
# Epoch 412, acc0.90, loss 0.2646, tol 0, val_acc0.91, val_loss0.2569
# Epoch 413, acc0.91, loss 0.2626, tol 0, val_acc0.92, val_loss0.2663
# Epoch 414, acc0.90, loss 0.2573, tol 0, val_acc0.92, val_loss0.2542
# Epoch 415, acc0.89, loss 0.2610, tol 0, val_acc0.91, val_loss0.2544
# Epoch 416, acc0.91, loss 0.2559, tol 0, val_acc0.91, val_loss0.2527
# Epoch 417, acc0.91, loss 0.2542, tol 0, val_acc0.90, val_loss0.2617
# Epoch 418, acc0.90, loss 0.2502, tol 0, val_acc0.90, val_loss0.2548
# Epoch 419, acc0.89, loss 0.2909, tol 0, val_acc0.90, val_loss0.2521
# Epoch 420, acc0.90, loss 0.2592, tol 0, val_acc0.92, val_loss0.2519
# Epoch 421, acc0.91, loss 0.2531, tol 0, val_acc0.89, val_loss0.2594
# Epoch 422, acc0.89, loss 0.2622, tol 0, val_acc0.90, val_loss0.2559
# Epoch 423, acc0.89, loss 0.2751, tol 0, val_acc0.92, val_loss0.2604
# Epoch 424, acc0.90, loss 0.2382, tol 0, val_acc0.92, val_loss0.2575
# Epoch 425, acc0.90, loss 0.2771, tol 0, val_acc0.92, val_loss0.2686
# Epoch 426, acc0.92, loss 0.2235, tol 0, val_acc0.92, val_loss0.2567
# Epoch 427, acc0.91, loss 0.2395, tol 0, val_acc0.90, val_loss0.2584
# Epoch 428, acc0.91, loss 0.2439, tol 0, val_acc0.89, val_loss0.2627
# Epoch 429, acc0.90, loss 0.2467, tol 0, val_acc0.92, val_loss0.2562
# Epoch 430, acc0.89, loss 0.2709, tol 0, val_acc0.92, val_loss0.2758
# Epoch 431, acc0.87, loss 0.3063, tol 0, val_acc0.92, val_loss0.2615
# Epoch 432, acc0.90, loss 0.2651, tol 0, val_acc0.92, val_loss0.2494
# Epoch 433, acc0.88, loss 0.2852, tol 0, val_acc0.89, val_loss0.2568
# Epoch 434, acc0.89, loss 0.2829, tol 0, val_acc0.92, val_loss0.2596
# Epoch 435, acc0.90, loss 0.2739, tol 0, val_acc0.91, val_loss0.2541
# Epoch 436, acc0.90, loss 0.2654, tol 0, val_acc0.90, val_loss0.2586
# Epoch 437, acc0.90, loss 0.2537, tol 0, val_acc0.92, val_loss0.2547
# Epoch 438, acc0.91, loss 0.2616, tol 0, val_acc0.92, val_loss0.2605
# Epoch 439, acc0.89, loss 0.2883, tol 0, val_acc0.93, val_loss0.2636
# Epoch 440, acc0.90, loss 0.2854, tol 0, val_acc0.93, val_loss0.2694
# Epoch 441, acc0.90, loss 0.2597, tol 0, val_acc0.93, val_loss0.2686
# Epoch 442, acc0.90, loss 0.2675, tol 0, val_acc0.92, val_loss0.2815
# Epoch 443, acc0.91, loss 0.2334, tol 0, val_acc0.92, val_loss0.2519
# Epoch 444, acc0.90, loss 0.2396, tol 0, val_acc0.92, val_loss0.2541
# Epoch 445, acc0.92, loss 0.2372, tol 0, val_acc0.91, val_loss0.2554
# Epoch 446, acc0.92, loss 0.2364, tol 0, val_acc0.92, val_loss0.2587
# Epoch 447, acc0.90, loss 0.2766, tol 0, val_acc0.91, val_loss0.2524
# Epoch 448, acc0.91, loss 0.2435, tol 0, val_acc0.91, val_loss0.2521
# Epoch 449, acc0.92, loss 0.2263, tol 0, val_acc0.90, val_loss0.2569
# Epoch 450, acc0.92, loss 0.2523, tol 0, val_acc0.91, val_loss0.2507
# Epoch 451, acc0.90, loss 0.2704, tol 0, val_acc0.92, val_loss0.2561
# Epoch 452, acc0.91, loss 0.2526, tol 0, val_acc0.92, val_loss0.2578
# Epoch 453, acc0.91, loss 0.2387, tol 0, val_acc0.92, val_loss0.2534
# Epoch 454, acc0.91, loss 0.2496, tol 0, val_acc0.92, val_loss0.2593
# Epoch 455, acc0.90, loss 0.2866, tol 0, val_acc0.92, val_loss0.2501
# Epoch 456, acc0.91, loss 0.2324, tol 0, val_acc0.92, val_loss0.2501
# Epoch 457, acc0.91, loss 0.2416, tol 0, val_acc0.92, val_loss0.2538
# Epoch 458, acc0.90, loss 0.2612, tol 0, val_acc0.92, val_loss0.2626
# Epoch 459, acc0.89, loss 0.2667, tol 0, val_acc0.92, val_loss0.2746
# Epoch 460, acc0.90, loss 0.2618, tol 0, val_acc0.92, val_loss0.2699
# Epoch 461, acc0.91, loss 0.2527, tol 0, val_acc0.92, val_loss0.2804
# Epoch 462, acc0.90, loss 0.2394, tol 0, val_acc0.92, val_loss0.2711
# Epoch 463, acc0.90, loss 0.2655, tol 0, val_acc0.92, val_loss0.2612
# Epoch 464, acc0.91, loss 0.2501, tol 0, val_acc0.92, val_loss0.2514
# Epoch 465, acc0.92, loss 0.2484, tol 0, val_acc0.91, val_loss0.2485
# Epoch 466, acc0.89, loss 0.2622, tol 0, val_acc0.92, val_loss0.2533
# Epoch 467, acc0.90, loss 0.2479, tol 0, val_acc0.92, val_loss0.2486
# Epoch 468, acc0.92, loss 0.2439, tol 0, val_acc0.92, val_loss0.2476
# Epoch 469, acc0.90, loss 0.2517, tol 0, val_acc0.92, val_loss0.2487
# Epoch 470, acc0.91, loss 0.2343, tol 0, val_acc0.92, val_loss0.2571
# Epoch 471, acc0.92, loss 0.2049, tol 0, val_acc0.93, val_loss0.2535
# Epoch 472, acc0.90, loss 0.2570, tol 0, val_acc0.93, val_loss0.2583
# Epoch 473, acc0.89, loss 0.2783, tol 0, val_acc0.92, val_loss0.2835
# Epoch 474, acc0.89, loss 0.2856, tol 0, val_acc0.92, val_loss0.2473
# Epoch 475, acc0.92, loss 0.2316, tol 0, val_acc0.93, val_loss0.2482
# Epoch 476, acc0.90, loss 0.2659, tol 0, val_acc0.92, val_loss0.2476
# Epoch 477, acc0.89, loss 0.2795, tol 0, val_acc0.91, val_loss0.2461
# Epoch 478, acc0.92, loss 0.2513, tol 0, val_acc0.91, val_loss0.2456
# Epoch 479, acc0.91, loss 0.2362, tol 0, val_acc0.91, val_loss0.2450
# Epoch 480, acc0.91, loss 0.2434, tol 0, val_acc0.92, val_loss0.2541
# Epoch 481, acc0.92, loss 0.2422, tol 0, val_acc0.91, val_loss0.2517
# Epoch 482, acc0.90, loss 0.2654, tol 0, val_acc0.91, val_loss0.2500
# Epoch 483, acc0.91, loss 0.2582, tol 0, val_acc0.90, val_loss0.2531
# Epoch 484, acc0.92, loss 0.2358, tol 0, val_acc0.91, val_loss0.2498
# Epoch 485, acc0.89, loss 0.2586, tol 0, val_acc0.91, val_loss0.2472
# Epoch 486, acc0.91, loss 0.2501, tol 0, val_acc0.93, val_loss0.2562
# Epoch 487, acc0.89, loss 0.2756, tol 0, val_acc0.92, val_loss0.2760
# Epoch 488, acc0.91, loss 0.2526, tol 0, val_acc0.93, val_loss0.2566
# Epoch 489, acc0.92, loss 0.2419, tol 0, val_acc0.91, val_loss0.2470
# Epoch 490, acc0.90, loss 0.2604, tol 0, val_acc0.91, val_loss0.2477
# Epoch 491, acc0.92, loss 0.2231, tol 0, val_acc0.92, val_loss0.2478
# Epoch 492, acc0.91, loss 0.2409, tol 0, val_acc0.90, val_loss0.2482
# Epoch 493, acc0.90, loss 0.2400, tol 0, val_acc0.91, val_loss0.2474
# Epoch 494, acc0.90, loss 0.2650, tol 0, val_acc0.89, val_loss0.2628
# Epoch 495, acc0.90, loss 0.2636, tol 0, val_acc0.91, val_loss0.2494
# Epoch 496, acc0.92, loss 0.2064, tol 0, val_acc0.92, val_loss0.2499
# Epoch 497, acc0.89, loss 0.2940, tol 0, val_acc0.93, val_loss0.2592
# Epoch 498, acc0.90, loss 0.2620, tol 0, val_acc0.93, val_loss0.2538
# Epoch 499, acc0.90, loss 0.2670, tol 0, val_acc0.93, val_loss0.2566
# Epoch 500, acc0.90, loss 0.2442, tol 0, val_acc0.91, val_loss0.2429
# Epoch 501, acc0.91, loss 0.2726, tol 0, val_acc0.90, val_loss0.2483
# Reach Max Epoch Number
# +----------------------+------------+
# |       Modules        | Parameters |
# +----------------------+------------+
# |  layers.0.0.attn_l   |     4      |
# |  layers.0.0.attn_r   |     4      |
# | layers.0.0.fc.weight |     4      |
# |  layers.0.1.attn_l   |     4      |
# |  layers.0.1.attn_r   |     4      |
# | layers.0.1.fc.weight |     4      |
# |  layers.0.2.attn_l   |     4      |
# |  layers.0.2.attn_r   |     4      |
# | layers.0.2.fc.weight |     4      |
# |  layers.0.3.attn_l   |     4      |
# |  layers.0.3.attn_r   |     4      |
# | layers.0.3.fc.weight |     4      |
# |  layers.0.4.attn_l   |     4      |
# |  layers.0.4.attn_r   |     4      |
# | layers.0.4.fc.weight |     4      |
# |  layers.0.5.attn_l   |     4      |
# |  layers.0.5.attn_r   |     4      |
# | layers.0.5.fc.weight |     4      |
# |  layers.0.6.attn_l   |     4      |
# |  layers.0.6.attn_r   |     4      |
# | layers.0.6.fc.weight |     4      |
# |  layers.0.7.attn_l   |     4      |
# |  layers.0.7.attn_r   |     4      |
# | layers.0.7.fc.weight |     4      |
# |  layers.1.0.attn_l   |     4      |
# |  layers.1.0.attn_r   |     4      |
# | layers.1.0.fc.weight |    128     |
# |   classify.weight    |     8      |
# |    classify.bias     |     2      |
# +----------------------+------------+
# Total Trainable Params: 242
# Epoch 0, acc0.51, loss 0.7036, tol 0, val_acc0.49, val_loss0.6987 -- checkpoint saved
# Epoch 1, acc0.51, loss 0.6940, tol 0, val_acc0.50, val_loss0.6944 -- checkpoint saved
# Epoch 2, acc0.49, loss 0.6954, tol 0, val_acc0.51, val_loss0.6926 -- checkpoint saved
# Epoch 3, acc0.52, loss 0.6928, tol 0, val_acc0.52, val_loss0.6917 -- checkpoint saved
# Epoch 4, acc0.50, loss 0.6939, tol 0, val_acc0.51, val_loss0.6911
# Epoch 5, acc0.54, loss 0.6881, tol 0, val_acc0.54, val_loss0.6868 -- checkpoint saved
# Epoch 6, acc0.57, loss 0.6847, tol 0, val_acc0.59, val_loss0.6809 -- checkpoint saved
# Epoch 7, acc0.61, loss 0.6775, tol 0, val_acc0.56, val_loss0.6739
# Epoch 8, acc0.59, loss 0.6726, tol 0, val_acc0.60, val_loss0.6640 -- checkpoint saved
# Epoch 9, acc0.63, loss 0.6541, tol 0, val_acc0.63, val_loss0.6430 -- checkpoint saved
# Epoch 10, acc0.64, loss 0.6421, tol 0, val_acc0.66, val_loss0.6237 -- checkpoint saved
# Epoch 11, acc0.63, loss 0.6405, tol 0, val_acc0.68, val_loss0.6222 -- checkpoint saved
# Epoch 12, acc0.65, loss 0.6309, tol 0, val_acc0.67, val_loss0.6116
# Epoch 13, acc0.64, loss 0.6260, tol 0, val_acc0.68, val_loss0.6086
# Epoch 14, acc0.69, loss 0.6005, tol 0, val_acc0.67, val_loss0.6047
# Epoch 15, acc0.67, loss 0.6080, tol 0, val_acc0.67, val_loss0.6026
# Epoch 16, acc0.69, loss 0.6037, tol 0, val_acc0.67, val_loss0.6018
# Epoch 17, acc0.66, loss 0.6297, tol 0, val_acc0.68, val_loss0.6005 -- checkpoint saved
# Epoch 18, acc0.67, loss 0.6077, tol 0, val_acc0.68, val_loss0.6009
# Epoch 19, acc0.67, loss 0.6114, tol 0, val_acc0.67, val_loss0.5993
# Epoch 20, acc0.67, loss 0.6218, tol 0, val_acc0.68, val_loss0.5983
# Epoch 21, acc0.68, loss 0.5914, tol 0, val_acc0.67, val_loss0.5979
# Epoch 22, acc0.70, loss 0.6012, tol 0, val_acc0.67, val_loss0.5955
# Epoch 23, acc0.68, loss 0.6085, tol 0, val_acc0.67, val_loss0.5966
# Epoch 24, acc0.68, loss 0.6007, tol 0, val_acc0.67, val_loss0.5953
# Epoch 25, acc0.69, loss 0.6031, tol 0, val_acc0.68, val_loss0.5943
# Epoch 26, acc0.69, loss 0.5996, tol 0, val_acc0.68, val_loss0.5946
# Epoch 27, acc0.69, loss 0.5920, tol 0, val_acc0.67, val_loss0.5942
# Epoch 28, acc0.67, loss 0.6112, tol 0, val_acc0.68, val_loss0.5981
# Epoch 29, acc0.67, loss 0.6170, tol 0, val_acc0.67, val_loss0.5934
# Epoch 30, acc0.68, loss 0.6068, tol 0, val_acc0.67, val_loss0.5944
# Epoch 31, acc0.68, loss 0.6068, tol 0, val_acc0.67, val_loss0.5930
# Epoch 32, acc0.69, loss 0.6003, tol 0, val_acc0.67, val_loss0.5918
# Epoch 33, acc0.69, loss 0.5979, tol 0, val_acc0.67, val_loss0.5968
# Epoch 34, acc0.66, loss 0.6088, tol 0, val_acc0.69, val_loss0.5984
# Epoch 35, acc0.69, loss 0.5837, tol 0, val_acc0.68, val_loss0.5960
# Epoch 36, acc0.67, loss 0.5958, tol 0, val_acc0.68, val_loss0.5979
# Epoch 37, acc0.68, loss 0.6003, tol 0, val_acc0.67, val_loss0.5907
# Epoch 38, acc0.69, loss 0.6069, tol 0, val_acc0.68, val_loss0.5900
# Epoch 39, acc0.68, loss 0.6009, tol 0, val_acc0.67, val_loss0.5925
# Epoch 40, acc0.69, loss 0.5939, tol 0, val_acc0.67, val_loss0.5900
# Epoch 41, acc0.69, loss 0.5908, tol 0, val_acc0.67, val_loss0.5892
# Epoch 42, acc0.70, loss 0.5809, tol 0, val_acc0.67, val_loss0.5920
# Epoch 43, acc0.70, loss 0.5891, tol 0, val_acc0.68, val_loss0.5877
# Epoch 44, acc0.70, loss 0.5847, tol 0, val_acc0.67, val_loss0.5907
# Epoch 45, acc0.68, loss 0.6097, tol 0, val_acc0.69, val_loss0.5902
# Epoch 46, acc0.68, loss 0.6061, tol 0, val_acc0.70, val_loss0.5895
# Epoch 47, acc0.68, loss 0.5888, tol 0, val_acc0.66, val_loss0.6066
# Epoch 48, acc0.70, loss 0.5999, tol 0, val_acc0.69, val_loss0.5843
# Epoch 49, acc0.68, loss 0.5915, tol 0, val_acc0.68, val_loss0.5860
# Epoch 50, acc0.69, loss 0.5982, tol 0, val_acc0.69, val_loss0.5820
# Epoch 51, acc0.70, loss 0.5976, tol 0, val_acc0.69, val_loss0.5803
# Epoch 52, acc0.73, loss 0.5630, tol 0, val_acc0.69, val_loss0.5793
# Epoch 53, acc0.69, loss 0.6005, tol 0, val_acc0.68, val_loss0.5807
# Epoch 54, acc0.67, loss 0.5910, tol 0, val_acc0.69, val_loss0.5760
# Epoch 55, acc0.71, loss 0.5650, tol 0, val_acc0.69, val_loss0.5749
# Epoch 56, acc0.68, loss 0.5978, tol 0, val_acc0.69, val_loss0.5737
# Epoch 57, acc0.69, loss 0.5785, tol 0, val_acc0.71, val_loss0.5766
# Epoch 58, acc0.70, loss 0.5757, tol 0, val_acc0.69, val_loss0.5683
# Epoch 59, acc0.71, loss 0.5617, tol 0, val_acc0.70, val_loss0.5666
# Epoch 60, acc0.71, loss 0.5698, tol 0, val_acc0.70, val_loss0.5621
# Epoch 61, acc0.74, loss 0.5358, tol 0, val_acc0.70, val_loss0.5576
# Epoch 62, acc0.71, loss 0.5861, tol 0, val_acc0.71, val_loss0.5518 -- checkpoint saved
# Epoch 63, acc0.71, loss 0.5708, tol 0, val_acc0.70, val_loss0.5543
# Epoch 64, acc0.74, loss 0.5557, tol 0, val_acc0.68, val_loss0.5597
# Epoch 65, acc0.73, loss 0.5492, tol 0, val_acc0.74, val_loss0.5249 -- checkpoint saved
# Epoch 66, acc0.72, loss 0.5508, tol 0, val_acc0.75, val_loss0.5292
# Epoch 67, acc0.75, loss 0.5282, tol 0, val_acc0.76, val_loss0.5080 -- checkpoint saved
# Epoch 68, acc0.75, loss 0.5206, tol 0, val_acc0.78, val_loss0.4832 -- checkpoint saved
# Epoch 69, acc0.76, loss 0.5279, tol 0, val_acc0.79, val_loss0.4737 -- checkpoint saved
# Epoch 70, acc0.77, loss 0.4939, tol 0, val_acc0.80, val_loss0.4623 -- checkpoint saved
# Epoch 71, acc0.77, loss 0.4788, tol 0, val_acc0.80, val_loss0.4557 -- checkpoint saved
# Epoch 72, acc0.76, loss 0.4822, tol 0, val_acc0.81, val_loss0.4532 -- checkpoint saved
# Epoch 73, acc0.78, loss 0.4723, tol 0, val_acc0.81, val_loss0.4515
# Epoch 74, acc0.76, loss 0.4912, tol 0, val_acc0.79, val_loss0.4635
# Epoch 75, acc0.79, loss 0.4866, tol 0, val_acc0.79, val_loss0.4597
# Epoch 76, acc0.77, loss 0.4851, tol 0, val_acc0.81, val_loss0.4442 -- checkpoint saved
# Epoch 77, acc0.79, loss 0.4608, tol 0, val_acc0.81, val_loss0.4409 -- checkpoint saved
# Epoch 78, acc0.80, loss 0.4432, tol 0, val_acc0.82, val_loss0.4397 -- checkpoint saved
# Epoch 79, acc0.77, loss 0.4913, tol 0, val_acc0.82, val_loss0.4378 -- checkpoint saved
# Epoch 80, acc0.80, loss 0.4482, tol 0, val_acc0.82, val_loss0.4357 -- checkpoint saved
# Epoch 81, acc0.79, loss 0.4603, tol 0, val_acc0.82, val_loss0.4348 -- checkpoint saved
# Epoch 82, acc0.77, loss 0.4902, tol 0, val_acc0.82, val_loss0.4338
# Epoch 83, acc0.77, loss 0.4682, tol 0, val_acc0.81, val_loss0.4359
# Epoch 84, acc0.79, loss 0.4722, tol 0, val_acc0.82, val_loss0.4339
# Epoch 85, acc0.79, loss 0.4605, tol 0, val_acc0.82, val_loss0.4330
# Epoch 86, acc0.80, loss 0.4503, tol 0, val_acc0.81, val_loss0.4356
# Epoch 87, acc0.77, loss 0.4736, tol 0, val_acc0.81, val_loss0.4342
# Epoch 88, acc0.79, loss 0.4796, tol 0, val_acc0.81, val_loss0.4415
# Epoch 89, acc0.80, loss 0.4384, tol 0, val_acc0.81, val_loss0.4306
# Epoch 90, acc0.80, loss 0.4524, tol 0, val_acc0.80, val_loss0.4325
# Epoch 91, acc0.81, loss 0.4504, tol 0, val_acc0.82, val_loss0.4264
# Epoch 92, acc0.80, loss 0.4676, tol 0, val_acc0.82, val_loss0.4249 -- checkpoint saved
# Epoch 93, acc0.78, loss 0.4718, tol 0, val_acc0.80, val_loss0.4317
# Epoch 94, acc0.77, loss 0.4938, tol 0, val_acc0.81, val_loss0.4400
# Epoch 95, acc0.77, loss 0.4922, tol 0, val_acc0.82, val_loss0.4253
# Epoch 96, acc0.78, loss 0.4731, tol 0, val_acc0.82, val_loss0.4244
# Epoch 97, acc0.78, loss 0.4889, tol 0, val_acc0.81, val_loss0.4250
# Epoch 98, acc0.80, loss 0.4743, tol 0, val_acc0.82, val_loss0.4206
# Epoch 99, acc0.78, loss 0.4807, tol 0, val_acc0.82, val_loss0.4256
# Epoch 100, acc0.79, loss 0.4608, tol 0, val_acc0.82, val_loss0.4234
# Epoch 101, acc0.79, loss 0.4808, tol 0, val_acc0.82, val_loss0.4164
# Epoch 102, acc0.80, loss 0.4543, tol 0, val_acc0.83, val_loss0.4152 -- checkpoint saved
# Epoch 103, acc0.80, loss 0.4489, tol 0, val_acc0.81, val_loss0.4151
# Epoch 104, acc0.82, loss 0.4375, tol 0, val_acc0.82, val_loss0.4114
# Epoch 105, acc0.80, loss 0.4442, tol 0, val_acc0.82, val_loss0.4085
# Epoch 106, acc0.80, loss 0.4468, tol 0, val_acc0.83, val_loss0.4094
# Epoch 107, acc0.79, loss 0.4753, tol 0, val_acc0.82, val_loss0.4048
# Epoch 108, acc0.79, loss 0.4667, tol 0, val_acc0.83, val_loss0.4042
# Epoch 109, acc0.79, loss 0.4649, tol 0, val_acc0.82, val_loss0.4131
# Epoch 110, acc0.81, loss 0.4550, tol 0, val_acc0.81, val_loss0.4014
# Epoch 111, acc0.80, loss 0.4603, tol 0, val_acc0.82, val_loss0.4099
# Epoch 112, acc0.81, loss 0.4274, tol 0, val_acc0.83, val_loss0.3970
# Epoch 113, acc0.80, loss 0.4540, tol 0, val_acc0.83, val_loss0.3937 -- checkpoint saved
# Epoch 114, acc0.82, loss 0.4124, tol 0, val_acc0.82, val_loss0.3981
# Epoch 115, acc0.80, loss 0.4525, tol 0, val_acc0.83, val_loss0.3927 -- checkpoint saved
# Epoch 116, acc0.80, loss 0.4513, tol 0, val_acc0.84, val_loss0.3957
# Epoch 117, acc0.80, loss 0.4497, tol 0, val_acc0.84, val_loss0.3938
# Epoch 118, acc0.80, loss 0.4460, tol 0, val_acc0.84, val_loss0.3904 -- checkpoint saved
# Epoch 119, acc0.81, loss 0.4276, tol 0, val_acc0.84, val_loss0.3873
# Epoch 120, acc0.79, loss 0.4667, tol 0, val_acc0.83, val_loss0.3873
# Epoch 121, acc0.79, loss 0.4641, tol 0, val_acc0.83, val_loss0.3869
# Epoch 122, acc0.80, loss 0.4452, tol 0, val_acc0.84, val_loss0.3988
# Epoch 123, acc0.82, loss 0.4204, tol 0, val_acc0.83, val_loss0.3845
# Epoch 124, acc0.80, loss 0.4266, tol 0, val_acc0.83, val_loss0.3880
# Epoch 125, acc0.79, loss 0.4563, tol 0, val_acc0.82, val_loss0.3879
# Epoch 126, acc0.81, loss 0.4285, tol 0, val_acc0.84, val_loss0.3882
# Epoch 127, acc0.82, loss 0.4158, tol 0, val_acc0.83, val_loss0.3867
# Epoch 128, acc0.81, loss 0.4413, tol 0, val_acc0.84, val_loss0.3815
# Epoch 129, acc0.79, loss 0.4513, tol 0, val_acc0.85, val_loss0.3840
# Epoch 130, acc0.80, loss 0.4358, tol 0, val_acc0.84, val_loss0.3796
# Epoch 131, acc0.81, loss 0.4001, tol 0, val_acc0.84, val_loss0.3855
# Epoch 132, acc0.81, loss 0.4330, tol 0, val_acc0.84, val_loss0.3779
# Epoch 133, acc0.80, loss 0.4453, tol 0, val_acc0.84, val_loss0.3774
# Epoch 134, acc0.80, loss 0.4482, tol 0, val_acc0.84, val_loss0.3772
# Epoch 135, acc0.80, loss 0.4374, tol 0, val_acc0.84, val_loss0.3823
# Epoch 136, acc0.80, loss 0.4448, tol 0, val_acc0.84, val_loss0.3916
# Epoch 137, acc0.81, loss 0.4184, tol 0, val_acc0.85, val_loss0.3792
# Epoch 138, acc0.80, loss 0.4385, tol 0, val_acc0.84, val_loss0.3773
# Epoch 139, acc0.80, loss 0.4346, tol 0, val_acc0.84, val_loss0.3764
# Epoch 140, acc0.82, loss 0.4221, tol 0, val_acc0.85, val_loss0.3777
# Epoch 141, acc0.79, loss 0.4491, tol 0, val_acc0.84, val_loss0.3783
# Epoch 142, acc0.80, loss 0.4458, tol 0, val_acc0.85, val_loss0.3733 -- checkpoint saved
# Epoch 143, acc0.81, loss 0.4319, tol 0, val_acc0.85, val_loss0.3733 -- checkpoint saved
# Epoch 144, acc0.80, loss 0.4353, tol 0, val_acc0.84, val_loss0.3744
# Epoch 145, acc0.81, loss 0.4209, tol 0, val_acc0.84, val_loss0.3737
# Epoch 146, acc0.82, loss 0.4168, tol 0, val_acc0.84, val_loss0.3726
# Epoch 147, acc0.79, loss 0.4481, tol 0, val_acc0.84, val_loss0.3882
# Epoch 148, acc0.81, loss 0.4265, tol 0, val_acc0.83, val_loss0.3776
# Epoch 149, acc0.80, loss 0.4408, tol 0, val_acc0.84, val_loss0.3759
# Epoch 150, acc0.81, loss 0.4338, tol 0, val_acc0.84, val_loss0.3831
# Epoch 151, acc0.83, loss 0.4116, tol 0, val_acc0.85, val_loss0.3779
# Epoch 152, acc0.81, loss 0.4200, tol 0, val_acc0.85, val_loss0.3777
# Epoch 153, acc0.81, loss 0.4374, tol 0, val_acc0.84, val_loss0.3741
# Epoch 154, acc0.80, loss 0.4322, tol 0, val_acc0.84, val_loss0.3733
# Epoch 155, acc0.80, loss 0.4325, tol 0, val_acc0.84, val_loss0.3718
# Epoch 156, acc0.81, loss 0.4238, tol 0, val_acc0.85, val_loss0.3794
# Epoch 157, acc0.82, loss 0.4230, tol 0, val_acc0.84, val_loss0.3723
# Epoch 158, acc0.80, loss 0.4372, tol 0, val_acc0.84, val_loss0.3816
# Epoch 159, acc0.80, loss 0.4356, tol 0, val_acc0.83, val_loss0.3790
# Epoch 160, acc0.79, loss 0.4661, tol 0, val_acc0.84, val_loss0.3720
# Epoch 161, acc0.80, loss 0.4395, tol 0, val_acc0.84, val_loss0.3748
# Epoch 162, acc0.79, loss 0.4373, tol 0, val_acc0.84, val_loss0.3731
# Epoch 163, acc0.81, loss 0.4197, tol 0, val_acc0.84, val_loss0.3782
# Epoch 164, acc0.81, loss 0.4186, tol 0, val_acc0.84, val_loss0.3717
# Epoch 165, acc0.80, loss 0.4449, tol 0, val_acc0.84, val_loss0.3705
# Epoch 166, acc0.82, loss 0.4029, tol 0, val_acc0.85, val_loss0.3750
# Epoch 167, acc0.81, loss 0.4458, tol 0, val_acc0.85, val_loss0.3678 -- checkpoint saved
# Epoch 168, acc0.80, loss 0.4359, tol 0, val_acc0.84, val_loss0.3679
# Epoch 169, acc0.82, loss 0.4355, tol 0, val_acc0.84, val_loss0.3748
# Epoch 170, acc0.82, loss 0.4098, tol 0, val_acc0.84, val_loss0.3723
# Epoch 171, acc0.79, loss 0.4466, tol 0, val_acc0.83, val_loss0.3727
# Epoch 172, acc0.78, loss 0.4611, tol 0, val_acc0.84, val_loss0.3893
# Epoch 173, acc0.80, loss 0.4309, tol 0, val_acc0.84, val_loss0.3694
# Epoch 174, acc0.81, loss 0.4318, tol 0, val_acc0.84, val_loss0.3691
# Epoch 175, acc0.79, loss 0.4435, tol 0, val_acc0.84, val_loss0.3716
# Epoch 176, acc0.80, loss 0.4556, tol 0, val_acc0.85, val_loss0.3889
# Epoch 177, acc0.82, loss 0.4182, tol 0, val_acc0.84, val_loss0.3732
# Epoch 178, acc0.81, loss 0.4457, tol 0, val_acc0.84, val_loss0.3717
# Epoch 179, acc0.80, loss 0.4356, tol 0, val_acc0.84, val_loss0.3694
# Epoch 180, acc0.82, loss 0.4090, tol 0, val_acc0.85, val_loss0.3677
# Epoch 181, acc0.81, loss 0.4155, tol 0, val_acc0.84, val_loss0.3693
# Epoch 182, acc0.83, loss 0.4112, tol 0, val_acc0.84, val_loss0.3659
# Epoch 183, acc0.80, loss 0.4582, tol 0, val_acc0.84, val_loss0.3668
# Epoch 184, acc0.80, loss 0.4304, tol 0, val_acc0.84, val_loss0.3702
# Epoch 185, acc0.80, loss 0.4372, tol 0, val_acc0.85, val_loss0.3704
# Epoch 186, acc0.79, loss 0.4542, tol 0, val_acc0.84, val_loss0.3688
# Epoch 187, acc0.82, loss 0.4151, tol 0, val_acc0.85, val_loss0.3865
# Epoch 188, acc0.81, loss 0.4319, tol 0, val_acc0.84, val_loss0.3702
# Epoch 189, acc0.80, loss 0.4350, tol 0, val_acc0.84, val_loss0.3711
# Epoch 190, acc0.81, loss 0.4403, tol 0, val_acc0.84, val_loss0.3694
# Epoch 191, acc0.83, loss 0.3932, tol 0, val_acc0.84, val_loss0.3686
# Epoch 192, acc0.79, loss 0.4286, tol 0, val_acc0.84, val_loss0.3704
# Epoch 193, acc0.81, loss 0.4318, tol 0, val_acc0.84, val_loss0.3685
# Epoch 194, acc0.81, loss 0.4218, tol 0, val_acc0.85, val_loss0.3673
# Epoch 195, acc0.82, loss 0.4294, tol 0, val_acc0.84, val_loss0.3718
# Epoch 196, acc0.81, loss 0.4248, tol 0, val_acc0.84, val_loss0.3652
# Epoch 197, acc0.81, loss 0.4157, tol 0, val_acc0.84, val_loss0.3707
# Epoch 198, acc0.82, loss 0.4180, tol 0, val_acc0.84, val_loss0.3703
# Epoch 199, acc0.80, loss 0.4348, tol 0, val_acc0.84, val_loss0.3647
# Epoch 200, acc0.82, loss 0.4080, tol 0, val_acc0.84, val_loss0.3653
# Epoch 201, acc0.82, loss 0.4200, tol 0, val_acc0.84, val_loss0.3661
# Epoch 202, acc0.82, loss 0.4129, tol 0, val_acc0.85, val_loss0.3751
# Epoch 203, acc0.80, loss 0.4360, tol 0, val_acc0.85, val_loss0.3645
# Epoch 204, acc0.82, loss 0.4099, tol 0, val_acc0.84, val_loss0.3671
# Epoch 205, acc0.80, loss 0.4418, tol 0, val_acc0.84, val_loss0.3665
# Epoch 206, acc0.82, loss 0.4089, tol 0, val_acc0.84, val_loss0.3708
# Epoch 207, acc0.82, loss 0.4099, tol 0, val_acc0.84, val_loss0.3686
# Epoch 208, acc0.82, loss 0.4181, tol 0, val_acc0.84, val_loss0.3637
# Epoch 209, acc0.80, loss 0.4368, tol 0, val_acc0.84, val_loss0.3682
# Epoch 210, acc0.79, loss 0.4347, tol 0, val_acc0.84, val_loss0.3655
# Epoch 211, acc0.82, loss 0.4239, tol 0, val_acc0.84, val_loss0.3685
# Epoch 212, acc0.81, loss 0.4303, tol 0, val_acc0.84, val_loss0.3622
# Epoch 213, acc0.81, loss 0.4051, tol 0, val_acc0.85, val_loss0.3794
# Epoch 214, acc0.81, loss 0.4251, tol 0, val_acc0.84, val_loss0.3655
# Epoch 215, acc0.82, loss 0.4120, tol 0, val_acc0.84, val_loss0.3627
# Epoch 216, acc0.82, loss 0.4218, tol 0, val_acc0.85, val_loss0.3746
# Epoch 217, acc0.81, loss 0.4276, tol 0, val_acc0.84, val_loss0.3628
# Epoch 218, acc0.82, loss 0.4269, tol 0, val_acc0.84, val_loss0.3638
# Epoch 219, acc0.84, loss 0.3925, tol 0, val_acc0.84, val_loss0.3688
# Epoch 220, acc0.83, loss 0.4063, tol 0, val_acc0.84, val_loss0.3638
# Epoch 221, acc0.81, loss 0.4309, tol 0, val_acc0.85, val_loss0.3767
# Epoch 222, acc0.81, loss 0.4353, tol 0, val_acc0.84, val_loss0.3659
# Epoch 223, acc0.79, loss 0.4419, tol 0, val_acc0.84, val_loss0.3653
# Epoch 224, acc0.82, loss 0.4257, tol 0, val_acc0.85, val_loss0.3691
# Epoch 225, acc0.82, loss 0.4118, tol 0, val_acc0.84, val_loss0.3676
# Epoch 226, acc0.81, loss 0.4146, tol 0, val_acc0.85, val_loss0.3735
# Epoch 227, acc0.81, loss 0.4261, tol 0, val_acc0.84, val_loss0.3619
# Epoch 228, acc0.82, loss 0.4213, tol 0, val_acc0.84, val_loss0.3635
# Epoch 229, acc0.80, loss 0.4415, tol 0, val_acc0.85, val_loss0.3613
# Epoch 230, acc0.80, loss 0.4492, tol 0, val_acc0.84, val_loss0.3635
# Epoch 231, acc0.80, loss 0.4130, tol 0, val_acc0.85, val_loss0.3739
# Epoch 232, acc0.82, loss 0.4094, tol 0, val_acc0.84, val_loss0.3614
# Epoch 233, acc0.82, loss 0.4169, tol 0, val_acc0.84, val_loss0.3681
# Epoch 234, acc0.81, loss 0.4286, tol 0, val_acc0.85, val_loss0.3859
# Epoch 235, acc0.81, loss 0.4173, tol 0, val_acc0.84, val_loss0.3648
# Epoch 236, acc0.82, loss 0.4212, tol 0, val_acc0.84, val_loss0.3858
# Epoch 237, acc0.81, loss 0.4227, tol 0, val_acc0.85, val_loss0.3670
# Epoch 238, acc0.81, loss 0.4290, tol 0, val_acc0.84, val_loss0.3643
# Epoch 239, acc0.83, loss 0.3895, tol 0, val_acc0.85, val_loss0.3710
# Epoch 240, acc0.83, loss 0.4070, tol 0, val_acc0.85, val_loss0.3589
# Epoch 241, acc0.80, loss 0.4480, tol 0, val_acc0.84, val_loss0.3607
# Epoch 242, acc0.81, loss 0.4439, tol 0, val_acc0.84, val_loss0.3602
# Epoch 243, acc0.80, loss 0.4414, tol 0, val_acc0.84, val_loss0.3621
# Epoch 244, acc0.82, loss 0.4232, tol 0, val_acc0.84, val_loss0.3635
# Epoch 245, acc0.83, loss 0.3999, tol 0, val_acc0.84, val_loss0.3618
# Epoch 246, acc0.82, loss 0.4061, tol 0, val_acc0.85, val_loss0.3634
# Epoch 247, acc0.81, loss 0.4115, tol 0, val_acc0.85, val_loss0.3628
# Epoch 248, acc0.83, loss 0.3997, tol 0, val_acc0.85, val_loss0.3577
# Epoch 249, acc0.79, loss 0.4428, tol 0, val_acc0.85, val_loss0.3694
# Epoch 250, acc0.82, loss 0.4090, tol 0, val_acc0.84, val_loss0.3588
# Epoch 251, acc0.81, loss 0.4335, tol 0, val_acc0.84, val_loss0.3576
# Epoch 252, acc0.82, loss 0.4211, tol 0, val_acc0.85, val_loss0.3675
# Epoch 253, acc0.83, loss 0.4186, tol 0, val_acc0.84, val_loss0.3660
# Epoch 254, acc0.83, loss 0.3991, tol 0, val_acc0.84, val_loss0.3729
# Epoch 255, acc0.81, loss 0.4283, tol 0, val_acc0.84, val_loss0.3680
# Epoch 256, acc0.80, loss 0.4430, tol 0, val_acc0.85, val_loss0.3692
# Epoch 257, acc0.81, loss 0.4277, tol 0, val_acc0.84, val_loss0.3595
# Epoch 258, acc0.82, loss 0.4234, tol 0, val_acc0.85, val_loss0.3627
# Epoch 259, acc0.82, loss 0.4261, tol 0, val_acc0.84, val_loss0.3637
# Epoch 260, acc0.81, loss 0.4227, tol 0, val_acc0.85, val_loss0.3587
# Epoch 261, acc0.82, loss 0.4324, tol 0, val_acc0.85, val_loss0.3610
# Epoch 262, acc0.82, loss 0.4203, tol 0, val_acc0.85, val_loss0.3702
# Epoch 263, acc0.81, loss 0.4268, tol 0, val_acc0.84, val_loss0.3630
# Epoch 264, acc0.81, loss 0.4467, tol 0, val_acc0.85, val_loss0.3602
# Epoch 265, acc0.83, loss 0.3987, tol 0, val_acc0.85, val_loss0.3660
# Epoch 266, acc0.83, loss 0.4213, tol 0, val_acc0.84, val_loss0.3571
# Epoch 267, acc0.81, loss 0.4281, tol 0, val_acc0.85, val_loss0.3599
# Epoch 268, acc0.81, loss 0.4218, tol 0, val_acc0.85, val_loss0.3597
# Epoch 269, acc0.82, loss 0.4015, tol 0, val_acc0.85, val_loss0.3660
# Epoch 270, acc0.81, loss 0.4245, tol 0, val_acc0.84, val_loss0.3612
# Epoch 271, acc0.81, loss 0.4287, tol 0, val_acc0.85, val_loss0.3694
# Epoch 272, acc0.81, loss 0.4146, tol 0, val_acc0.85, val_loss0.3574
# Epoch 273, acc0.83, loss 0.4043, tol 0, val_acc0.85, val_loss0.3608
# Epoch 274, acc0.83, loss 0.4044, tol 0, val_acc0.85, val_loss0.3667
# Epoch 275, acc0.82, loss 0.4100, tol 0, val_acc0.84, val_loss0.3592
# Epoch 276, acc0.83, loss 0.3987, tol 0, val_acc0.83, val_loss0.3708
# Epoch 277, acc0.82, loss 0.4122, tol 0, val_acc0.85, val_loss0.3595
# Epoch 278, acc0.81, loss 0.4228, tol 0, val_acc0.85, val_loss0.3651
# Epoch 279, acc0.83, loss 0.3952, tol 0, val_acc0.85, val_loss0.3590
# Epoch 280, acc0.80, loss 0.4285, tol 0, val_acc0.84, val_loss0.3580
# Epoch 281, acc0.83, loss 0.3927, tol 0, val_acc0.85, val_loss0.3661
# Epoch 282, acc0.82, loss 0.4217, tol 0, val_acc0.84, val_loss0.3642
# Epoch 283, acc0.83, loss 0.3980, tol 0, val_acc0.84, val_loss0.3553
# Epoch 284, acc0.82, loss 0.3947, tol 0, val_acc0.85, val_loss0.3551
# Epoch 285, acc0.83, loss 0.4144, tol 0, val_acc0.85, val_loss0.3590
# Epoch 286, acc0.84, loss 0.3952, tol 0, val_acc0.84, val_loss0.3569
# Epoch 287, acc0.83, loss 0.4008, tol 0, val_acc0.85, val_loss0.3677
# Epoch 288, acc0.81, loss 0.4247, tol 0, val_acc0.84, val_loss0.3688
# Epoch 289, acc0.80, loss 0.4456, tol 0, val_acc0.85, val_loss0.3556
# Epoch 290, acc0.82, loss 0.4037, tol 0, val_acc0.85, val_loss0.3635
# Epoch 291, acc0.83, loss 0.3850, tol 0, val_acc0.85, val_loss0.3590
# Epoch 292, acc0.83, loss 0.3896, tol 0, val_acc0.85, val_loss0.3547
# Epoch 293, acc0.83, loss 0.4149, tol 0, val_acc0.85, val_loss0.3561
# Epoch 294, acc0.82, loss 0.3870, tol 0, val_acc0.85, val_loss0.3584
# Epoch 295, acc0.81, loss 0.4075, tol 0, val_acc0.85, val_loss0.3562
# Epoch 296, acc0.82, loss 0.4009, tol 0, val_acc0.84, val_loss0.3525
# Epoch 297, acc0.83, loss 0.4096, tol 0, val_acc0.84, val_loss0.3537
# Epoch 298, acc0.80, loss 0.4442, tol 0, val_acc0.84, val_loss0.3800
# Epoch 299, acc0.83, loss 0.4061, tol 0, val_acc0.85, val_loss0.3566
# Epoch 300, acc0.81, loss 0.4201, tol 0, val_acc0.84, val_loss0.3548
# Epoch 301, acc0.84, loss 0.3796, tol 0, val_acc0.86, val_loss0.3602
# Epoch 302, acc0.83, loss 0.3916, tol 0, val_acc0.85, val_loss0.3567
# Epoch 303, acc0.83, loss 0.4173, tol 0, val_acc0.85, val_loss0.3524
# Epoch 304, acc0.80, loss 0.4413, tol 0, val_acc0.85, val_loss0.3514
# Epoch 305, acc0.84, loss 0.3927, tol 0, val_acc0.85, val_loss0.3588
# Epoch 306, acc0.81, loss 0.4300, tol 0, val_acc0.85, val_loss0.3557
# Epoch 307, acc0.81, loss 0.4200, tol 0, val_acc0.85, val_loss0.3538
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-14abc9d49639> in <module>()
#      88         val_acc = 0
#      89         val_loss = 0
# ---> 90         predictions_val = []
#      91
#      92         for b in range(len(val_graphs)):
#
# KeyboardInterrupt:
